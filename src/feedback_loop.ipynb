# %% [markdown]
# Configuration

# %%
model_name = "llava"      # "llava", "llavanext", "llamavision", "llavacot", "llava-finetuned"
template_id = 'r1'
domain = 'Construction'
root_dir = '/content/drive/MyDrive/'
save_dir = f'{root_dir}/results_feedback'
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Install

# %%
# @title
# %%capture
# !pip install json-repair
# !pip install --upgrade transformers
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Import

# %%
# @title
# %%capture
import time
import pandas as pd
from tqdm.notebook import tqdm

import torch
from PIL import Image
from transformers import LlavaForConditionalGeneration, LlavaNextForConditionalGeneration, MllamaForConditionalGeneration, AutoProcessor

import re
import ast
from json_repair import repair_json

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import accuracy_score, f1_score, classification_report
from collections import defaultdict

from google.colab import drive
drive.mount('/content/drive')

from IPython.display import HTML, display, clear_output
def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

import os

if not os.path.exists(save_dir):
    os.makedirs(save_dir)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Model

# %%
# @title
# %%capture
if model_name == "llava":
    model_id = "llava-hf/llava-1.5-7b-hf"
    model = LlavaForConditionalGeneration.from_pretrained(model_id, device_map="auto", dtype=torch.float16)
    assistant_token = 'ASSISTANT:'

elif model_name == "llava-finetuned":
    model_id = "Stephanienzz/llava-TrafficOnly-hazard-explanation-r1.0.5"
    model = LlavaForConditionalGeneration.from_pretrained(model_id, device_map="auto", dtype=torch.float16)
    assistant_token = 'ASSISTANT:'

elif model_name == "llavanext":
    model_id = "llava-hf/llava-v1.6-mistral-7b-hf"
    model = LlavaNextForConditionalGeneration.from_pretrained(model_id, device_map="auto", dtype=torch.float16)
    assistant_token = '[/INST]'

elif model_name== "llamavision":
    model_id = "meta-llama/Llama-3.2-11B-Vision-Instruct"
    model = MllamaForConditionalGeneration.from_pretrained(model_id, device_map="auto", dtype=torch.float16)
    assistant_token = '<|eot_id|><|start_header_id|>assistant<|end_header_id|>'

elif model_name == "llavacot":
    model_id = "Xkev/Llama-3.2V-11B-cot"
    model = MllamaForConditionalGeneration.from_pretrained(model_id, device_map="auto", dtype=torch.float16)
    assistant_token = '<|eot_id|><|start_header_id|>assistant<|end_header_id|>'

model.tie_weights()
processor = AutoProcessor.from_pretrained(model_id, use_fast=True)
processor.tokenizer.padding_side = "left"
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Rules

# %%
# @title
rule_description = {

"Construction": {

"Ladder Use" : """Ladder Use:
* Ladders shall be used only on stable and level surfaces unless secured to prevent accidental displacement. [1926.1053(b)(6)]
* The area around the top and bottom of ladders shall be kept clear. [1926.1053(b)(9)]
* When ascending or descending a ladder, the user shall face the ladder. [1926.1053(b)(20)]
* Each employee shall use at least one hand to grasp the ladder when progressing up and/or down the ladder. [1926.1053(b)(21)]
* An employee shall not carry any object or load that could cause the employee to lose balance and fall. [1926.1053(b)(22)]""",

"Protective Equipment": """Protective Equipment:
* Employees working in areas where there is a possible danger of head injury from impact, or from falling or flying objects, or from electrical shock and burns, shall be protected by protective helmets. [1926.100(a)]
* Each affected employee uses appropriate eye or face protection when exposed to eye or face hazards from flying particles, molten metal, liquid chemicals, acids or caustic liquids, chemical gases or vapors, or potentially injurious light radiation. [1926.102(a)(1)]
* Each employee on a walking/working surface (horizontal and vertical surface) with an unprotected side or edge which is 6 feet (1.8 m) or more above a lower level shall be protected from falling by the use of guardrail systems, safety net systems, or personal fall arrest systems. [1926.501(b)(1)]""",

"Fire Risk" : """Fire Safety:
* Smoking shall be prohibited at or in the vicinity of operations which constitute a fire hazard, and shall be conspicuously posted: "No Smoking or Open Flame." [1926.151(a)(3)]
* If the object to be welded, cut, or heated cannot be moved and if all the fire hazards cannot be removed, positive means shall be taken to confine the heat, sparks, and slag, and to protect the immovable fire hazards from them. [1926.352(b)]""",

"Crane Use" : """Crane Use:
* The operator must not engage in any practice or activity that diverts his/her attention while actually engaged in operating the equipment, such as the use of cellular phones (other than when used for signal communications). [1926.1417(d)]
* Erect and maintain control lines, warning lines, railings or similar barriers to mark the boundaries of the hazard areas. [1926.1424(a)(2)(ii)]
* While the operator is not moving a suspended load, no employee must be within the fall zone [1926.1425(b)]""",

"Scaffolding Risk" : """Scaffold Safety:
* Each platform on all working levels of scaffolds shall be fully planked or decked between the front uprights and the guardrail supports [1926.451(b)(1)]
* Guardrail systems shall be installed along all open sides and ends of platforms. [1926.451(g)(4)]
* The top edge height of toprails or equivalent member on supported scaffolds shall be installed between 38 inches (0.97 m) and 45 inches (1.2 m) above the platform surface. [1926.451(g)(4)(ii)]
* In addition to wearing hardhats each employee on a scaffold shall be provided with additional protection from falling hand tools, debris, and other small objects through the installation of toeboards, screens, or guardrail systems, or through the erection of debris nets, catch platforms, or canopy structures that contain or deflect the falling objects. [1926.451(h)(1)]""",
},

"Warehouse" : {

"Surface Condition" : """Surface Condition:
* All places of employment, passageways, storerooms, service rooms, and walking-working surfaces are kept in a clean, orderly, and sanitary condition. [29 CFR 1910.22(a)(1)]
* The floor of each workroom is maintained in a clean and, to the extent feasible, in a dry condition. When wet processes are used, drainage must be maintained and, to the extent feasible, dry standing places, such as false floors, platforms, and mats must be provided. [29 CFR 1910.22(a)(2)]
* Walking-working surfaces are maintained free of hazards such as sharp or protruding objects, loose boards, corrosion, leaks, spills, snow, and ice. [29 CFR 1910.22(a)(3)]""",

"Ergonomic Lifting" : """Ergonomic Lifting:
* Safe lifting involves: Holding the load close to your body at waist height. Never lift a heavy item above shoulder level. Never carry a load that obstructs your vision. [General Duty Clause, Section 5(a)(1)]
* The following points should be considered: The start and finish height of the load should be a suitable level above the floor, that is, between mid-thigh to shoulder height, preferably at about waist height. The back should not be twisted or bent sideways. Lifting with one hand should be avoided. [NOHSC:2005(1990) 5.66] """,

"Protective Equipment": """Protective Equipment:
* Each affected employee uses appropriate eye or face protection when exposed to eye or face hazards from flying particles, molten metal, liquid chemicals, acids or caustic liquids, chemical gases or vapors, or potentially injurious light radiation [29 CFR 1910.133(a)(1)]
* each affected employee wears a protective helmet when working in areas where there is a potential for injury to the head from falling objects. [29 CFR 1910.135(a)(1)]
* Personal fall protection systems must be worn with the attachment point of the body harness located in the center of the employee's back near shoulder level. The attachment point may be located in the pre-sternal position if the free fall distance is limited to 2 feet (0.6 m) or less. [29 CFR 1910.140(c)(22)]""",

"Ladder Use" : """Ladder Use:
* Ladders are used only on stable and level surfaces; [29 CFR 1910.23(c)(4)]
* Each employee faces the ladder when climbing up or down it; [29 CFR 1910.23(b)(11)]
* Each employee uses at least one hand to grasp the ladder when climbing up and down it; and [29 CFR 1910.23(b)(12)]
* No employee carries any object or load that could cause the employee to lose balance and fall while climbing up or down the ladder. [29 CFR 1910.23(b)(13)]""",

"Forklift Use" : """Forklift Use:
* No person shall be allowed to stand or pass under the elevated portion of any truck, whether loaded or empty. [29 CFR 1910.178(m)(2)]
* All traffic regulations shall be observed, including authorized plant speed limits. A safe distance shall be maintained approximately three truck lengths from the truck ahead, and the truck shall be kept under control at all times. [1910.178(n)(1)]
* The driver shall be required to look in the direction of, and keep a clear view of the path of travel. [1910.178(n)(6)]""",
},

"Traffic": {

"Driving Distraction" : """Driver Control:
* Distracted driving: Distracted driving is any activity that diverts attention from driving, including talking or texting on your phone, eating and drinking, talking to people in your vehicle, fiddling with the stereo, entertainment or navigation system — anything that takes your attention away from the task of safe driving. [National Highway Traffic Safety Administration]
* Driver to have proper control of a vehicle etc.: A person must not drive a vehicle if a person or an animal is in the driver's lap. [ROAD SAFETY ROAD RULES 2017 - REG 297 (1A)]
* Touching or looking at portable devices in motor vehicles: The driver of a motor vehicle must not touch a portable device in the motor vehicle while the vehicle is moving, or is stationary but not parked. [ROAD SAFETY ROAD RULES 2017 - REG 304J (1)]
* Duty of driver to avoid driving while fatigued: A person must not drive a fatigue-regulated heavy vehicle on a road while the person is impaired by fatigue. [HEAVY VEHICLE NATIONAL LAW (ACT) - SECT 228 (1)]""",

"Traffic Rules" : """Road Rules:
* Giving way at a pedestrian crossing: A driver must give way to any pedestrian on or entering a pedestrian crossing. [ROAD SAFETY ROAD RULES 2017 - REG 81 (2)]
* Overtaking or passing a vehicle at a children's crossing or pedestrian crossing: A driver approaching a children's crossing, or pedestrian crossing, must not overtake or pass a vehicle that is travelling in the same direction as the driver and is stopping, or has stopped, to give way to a pedestrian at the crossing. [ROAD SAFETY ROAD RULES 2017 - REG 82]
* Proceeding through a red traffic light: If traffic lights at an intersection or marked foot crossing are showing a red traffic light, a driver must not enter the intersection or marked foot crossing. [ROAD SAFETY ROAD RULES 2017 - REG 59]
* Driving on a one-way service road: A driver on the part of the road that is a service road must drive in the same direction as a vehicle travelling on the part of the road closest to the service road is required to travel. [ROAD SAFETY ROAD RULES 2017 - REG 136]
* Opening doors and getting out of a vehicle etc.: A person must not cause a hazard to any person or vehicle by opening a door of a vehicle, leaving a door of a vehicle open, or getting off, or out of, a vehicle. [ROAD SAFETY ROAD RULES 2017 - REG 269 (3)]
* Driving within a single marked lane or line of traffic: A driver on a multi-lane road must drive so the driver's vehicle is completely in a marked lane [ROAD SAFETY ROAD RULES 2017 - REG 146 (1)]
* Emergency stopping lane only signs: A driver must not drive in an emergency stopping lane. [ROAD SAFETY ROAD RULES 2017 - REG 95 (1)]
* Stopping in an emergency stopping lane: A driver must not stop in an emergency stopping lane. [ROAD SAFETY ROAD RULES 2017 - REG 178]
* Parking in parking bays: A driver must position the driver's vehicle completely within a single parking bay. [ROAD SAFETY ROAD RULES 2017 - REG 211 (2)]
* Obstructing access to and from a footpath, driveway etc.: A driver must not stop on a road in a position that obstructs access by vehicles or pedestrians to or from a footpath ramp or a similar way of access to a footpath, or a bicycle path or passageway. [ROAD SAFETY ROAD RULES 2017 - REG 198 (1)]""",

"Pedestrian Crossing" : """Pedestrian Rules:
* Crossing a road—general: A pedestrian crossing a road— (a) must cross by the shortest safe route; and (b) must not stay on the road longer than necessary to cross the road safely. [ROAD SAFETY ROAD RULES 2017 - REG 230 (1)]
* Crossing a road at pedestrian lights: If the pedestrian lights show a red pedestrian light and the pedestrian has not already started crossing the intersection or road, the pedestrian must not start to cross until the pedestrian lights change to green. [ROAD SAFETY ROAD RULES 2017 - REG 231 (2)]
* Pedestrians not to cause a traffic hazard or obstruction: A pedestrian must not cause a traffic hazard by moving into the path of a driver. [ROAD SAFETY ROAD RULES 2017 - REG 236 (1)]""",

"Road Condition" : """Driving Conditions:
* Obligations of road users: A person who drives a motor vehicle on a highway must drive in a safe manner having regard to all the relevant factors. [ROAD SAFETY ACT 1986 - SECT 17A (1)]
* The relevant factors include the following— (a) the physical characteristics of the road; (b) the prevailing weather conditions; (c) the level of visibility; (d) the condition of any vehicle the person is driving or riding on the highway; (e) the prevailing traffic conditions; (f) the relevant road laws and advisory signs; (g) the physical and mental condition of the driver or road user. [ROAD SAFETY ACT 1986 - SECT 17A (2A)]
* Relevant vehicle not to be used in hazardous area without hazardous area authority: A person must not use a relevant vehicle in a hazardous area. [ROAD SAFETY (VEHICLES) REGULATIONS 2021 - REG 299]""",

"Vehicle Load": """Vehicle Load:
* Carrying goods in addition to a large indivisible items: A load-carrying vehicle must not carry more than 1 large indivisible item. [HEAVY VEHICLE (MASS, DIMENSION AND LOADING) NATIONAL REGULATION - SCHEDULE 8 Division 2 - Load-carrying vehicles 13 (1)]
* Load restraint requirement: The following requirements apply to a vehicle that is carrying a load— (a) the load must be secured by a means that is appropriate to the vehicle and the nature of the load; (b) the load must be placed and secured on the vehicle in a way that prevents, or would be likely to prevent, the load or any part of the load from— (i) hanging or projecting from the vehicle; or (ii) becoming dislodged or falling from the vehicle; (c) the load must not be placed or secured on the vehicle in a way that makes the vehicle unstable; (d) the load must be placed and secured on the vehicle in compliance with the performance standards recommended in the Load Restraint Guide for Light Vehicles 2018, published by the National Transport Commission. [ROAD SAFETY (VEHICLES) REGULATIONS 2021 - REG 285]""",
}
}

custom_rules = rule_description[domain]
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Prompt

# %%
# @title
RULE_TEMPLATE = "coded-rules" # 'bulletpoints', 'bulletpoints-with-header', 'coded-rules'

META_PROMPT_TEMPLATE = """
{instruction_text}

{safety_rules}{augmented_context}

{response_format}"""

templates = {

## JSON classification explanation

"r1": {
    "instruction_text": """Analyze the image against the rule set. If the rule set clearly applies to the scenario depicted, determine whether it is "Complied" or "Violated". If the rule set does not clearly apply, return "Not Applicable".""",
    "augmented_context": "",
    "response_format": """Think step-by-step before giving your final answer. Respond only with a JSON object containing the following keys:
  - "explanation": an explanation for the classification made.
  - "classification": one of "Complied", "Violated", or "Not Applicable".
  - "confidence": a numeric value between 0 and 1 estimating both the likelihood that the classification is correct and how free it is from ambiguity.""",
 },

"r1.0.5": {
    "instruction_text": """Analyze the image against the rule set.""",
    "augmented_context": "",
    "response_format": """Respond only with a JSON object containing the following keys:
  - "classification": one of "Complied", "Violated", or "Not Applicable".
  - "explanation": an explanation for the classification made.""",
 },


 "r2": {
    "instruction_text": """Analyze the image against the rule set.""",
    "augmented_context": "",
    "response_format": """Respond only with a JSON object containing the following keys:
  - "explanation": an explanation for the classification made.
  - "classification": one of "Complied", "Violated", or "Not Applicable".""",
 },

# Amanda's prompt
"r4": {
  "instruction_text": """
  - Analyze the image against the rule set.
  - ONLY describe what you can clearly see in the image, and treat anything outside the frame as unknown.
  - Use object detection, pose estimation, and spatial awareness to confirm what's happening.
  - If the rule set clearly applies to the scenario depicted, determine the state of compliance. Otherwise (including if unsure), state "Not Applicable".
  - If you would need to invent, infer, or guess to decide (e.g., object partially occluded, identity ambiguous, or evidence unclear), classify as "Not Applicable".""",
    "augmented_context": "",
    "response_format": """Respond only with a JSON object containing exactly these keys:
  - "classification": one of "Complied", "Violated", or "Not Applicable"
  - "explanation": a concise explanation for the classification made
  - "confidence": a numeric confidence (0 to 1) that your classification is correct""",
},
}
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Helper Functions

# %%
# @title
import re
import json

def parse_ruleset(raw_text, ruleset_id="RS-1"):
    lines = raw_text.strip().splitlines()
    ruleset_title = lines[0].rstrip(":").strip()
    rule_lines = [line.strip() for line in lines[1:] if line.strip()]

    rules = []
    rule_id_counter = 1

    for line in rule_lines:
        match = re.match(r"^\* (.*?):\s*(.*?)\s*\[(.*?)\]$", line)
        if match:
            title, definition, source = match.groups()
        else:
            source_match = re.search(r"\[(.*?)\]$", line)
            source = source_match.group(1) if source_match else "Unknown"
            definition = re.sub(r"^\*\s*", "", line)
            definition = re.sub(r"\s*\[.*?\]$", "", definition).strip()
            title = "General rule"

        rules.append({
            "ID": f"{ruleset_id}.{rule_id_counter}",
            "Title": title.strip(),
            "Definition": definition.strip(),
            "Source": source.strip()
        })
        rule_id_counter += 1

    ruleset = {
        "Rule Set": {
            "ID": ruleset_id,
            "Title": ruleset_title,
            "Rules": rules
        }
    }
    return ruleset

def json_to_ruleset(ruleset_json, indent_spaces = 2):
    ruleset = ruleset_json["Rule Set"]
    rule_lines = [f"Rule Set: {ruleset['Title']} (ID: {ruleset['ID']})"]
    indent = " " * indent_spaces

    for rule in ruleset["Rules"]:
        rule_lines.append(f"{indent}Rule ID: {rule['ID']}")
        rule_lines.append(f"{indent*indent_spaces}Title: {rule['Title']}")
        rule_lines.append(f"{indent*indent_spaces}Definition: {rule['Definition']}")
        rule_lines.append(f"{indent*indent_spaces}Source: {rule['Source']}")

    return "\n".join(rule_lines)

def get_template(template_id, rule_key, feedbacks = None, rule_template = RULE_TEMPLATE):

    temp = templates.get(template_id)
    instruction_text = temp.get('instruction_text')
    augmented_context = temp.get('augmented_context')

    if feedbacks:
        augmented_context = "\n\nMeta-rules: \n"
        augmented_context += "\n".join(feedbacks.get('general', ['']))
        if feedbacks.get(rule_key, ''):
            augmented_context += "\n".join(feedbacks.get(rule_key, ['']))

    response_format = temp.get('response_format')

    if rule_template == 'bulletpoints':

        if isinstance(rule_key, list):
            ruleset_text = "Rule Set: \n\n"
            for i, r in enumerate(rule_key, start=1):
                safety_rules = custom_rules[r].strip()
                rule_name = safety_rules.split(':\n')[0].strip()
                rule_description = safety_rules[len(safety_rules.split(':\n')[0])+1:]
                ruleset_text += rule_description
                ruleset_text += "\n\n"

        elif rule_key == 'all':
            ruleset_text = "Rule Set: \n\n"
            for i, (k, v) in enumerate(custom_rules.items(), start = 1):
                safety_rules = v.strip()
                rule_name = safety_rules.split(':\n')[0].strip()
                rule_description = safety_rules[len(safety_rules.split(':\n')[0])+1:]
                ruleset_text += rule_description
                ruleset_text += "\n\n"
        else:
            safety_rules = custom_rules[rule_key].strip()
            rule_name = safety_rules.split(':\n')[0].strip()
            rule_description = safety_rules[len(safety_rules.split(':\n')[0])+1:]
            ruleset_text = f'Rule Set: {rule_description}"'

    elif rule_template == 'bulletpoints-with-header':

        if isinstance(rule_key, list):
          ruleset_text = "Rule Set: \n\n"
          for i, r in enumerate(rule_key, start=1):
              safety_rules = custom_rules[r].strip()
              rule_name = safety_rules.split(':\n')[0].strip()
              rule_description = safety_rules[len(safety_rules.split(':\n')[0])+1:]
              ruleset_text += f'{i}. Rule: "{rule_name}" \nRelevant Sub-Rules: {rule_description}"'
              ruleset_text += "\n\n"

        elif rule_key == 'all':
            ruleset_text = "Rule Set: \n\n"
            for i, (k, v) in enumerate(custom_rules.items(), start = 1):
                safety_rules = v.strip()
                rule_name = safety_rules.split(':\n')[0].strip()
                rule_description = safety_rules[len(safety_rules.split(':\n')[0])+1:]
                ruleset_text += f'{i}. Rule: "{rule_name}" \nRelevant Sub-Rules: {rule_description}"'
                ruleset_text += "\n\n"
        else:
            safety_rules = custom_rules[rule_key].strip()
            rule_name = safety_rules.split(':\n')[0].strip()
            rule_description = safety_rules[len(safety_rules.split(':\n')[0])+1:]
            ruleset_text = f'Rule Set: "{rule_name}" \nRelevant Sub-Rules: {rule_description}"'

    elif rule_template == 'coded-rules':

        if isinstance(rule_key, list):
            ruleset_text = []
            for i, r in enumerate(rule_key, start=1):
                safety_rules = custom_rules[r].strip()
                ruleset_json = parse_ruleset(safety_rules, ruleset_id=f"RS-{i}")
                ruleset_text.append(json_to_ruleset(ruleset_json))

            ruleset_text = '\n\n'.join(ruleset_text).strip()

        elif rule_key == 'all':
            ruleset_text = []
            for i, (k, v) in enumerate(custom_rules.items(), start = 1):
                safety_rules = v.strip()
                ruleset_json = parse_ruleset(safety_rules, ruleset_id=f"RS-{i}")
                ruleset_text.append(json_to_ruleset(ruleset_json))

            ruleset_text = '\n\n'.join(ruleset_text).strip()

        else:
            safety_rules = custom_rules[rule_key].strip()
            ruleset_json = parse_ruleset(safety_rules, ruleset_id="RS-1")
            ruleset_text = json_to_ruleset(ruleset_json).strip()

    return META_PROMPT_TEMPLATE.format(instruction_text=instruction_text, safety_rules=ruleset_text,
                                       augmented_context=augmented_context, response_format=response_format)


def load_image(image_path):
    img = Image.open(image_path)
    if img.mode != 'RGB':
        img = img.convert('RGB')
    return img

def flatten_dict(d):
    flat = {}

    def _flatten(obj):
        if isinstance(obj, dict):
            for k, v in obj.items():
                if isinstance(v, dict) or isinstance(v, list):
                    _flatten(v)
                else:
                    flat[k] = v
        elif isinstance(obj, list):
            for item in obj:
                _flatten(item)

    _flatten(d)
    return flat

def extract_json_prediction(raw_pred):
    try:
        prediction = flatten_dict(ast.literal_eval(repair_json(raw_pred)))

    except (ValueError, SyntaxError):
        return 'Unknown', '', -1

    classification = prediction.get('classification', prediction.get('guess', 'Unknown'))
    try:
        reasoning = prediction.get('reasoning', ast.literal_eval(repair_json(raw_pred))['reasoning'])
    except:
        reasoning = ''
    explanation = prediction.get('explanation', '')
    confidence = float(prediction.get('confidence', -1))

    classification = sanitize_pred_label(classification)

    return classification, reasoning, explanation, confidence

def extract_xml_prediction(raw_pred):

    matching = re.search(r"<classification>\s*([^<]*?)\s*(?:</classification>|(?=<))", str(raw_pred), re.DOTALL)
    matching1 = re.search(r"<guess>\s*([^<]*?)\s*(?:</guess>|(?=<))", str(raw_pred), re.DOTALL)

    if matching:
        classification = matching1.group(1).strip()
    elif matching1:
        classification = matching1.group(1).strip()
    else:
        classification = 'Unknown'

    matching2 = re.search(r"<reasoning>(.*?)</reasoning>", str(raw_pred), re.DOTALL)
    matching3 = re.search(r"<explanation>\s*([^<]*?)\s*(?:</explanation>|(?=<))", str(raw_pred), re.DOTALL)
    matching4 = re.search(r"<confidence>\s*([^<]*?)\s*(?:</confidence>|(?=<))", str(raw_pred), re.DOTALL)

    if matching2:
        reasoning = matching2.group(1).strip()
    else:
        reasoning = ''
    if matching3:
        explanation = matching3.group(1).strip()
    else:
        explanation = ''

    if matching4:
        try:
            confidence = float(matching4.group(1).strip())
        except:
            confidence = -1
    else:
        confidence = -1

    classification = sanitize_pred_label(classification)

    return classification, reasoning, explanation, confidence


def sanitize_pred_label(pred_label):

    pred_label = pred_label.replace('Non-Compliant', 'Violated')
    pred_label = pred_label.replace('Compliant', 'Complied')
    pred_label = pred_label.replace('Non-Applicable', 'Not Applicable')

    pred_label = pred_label.strip().title()

    return pred_label if pred_label in ['Complied', 'Violated', 'Not Applicable'] else 'Unknown'

def get_model_outputs(img, template, max_new_tokens = 256):
    messages = [{"role": "user", "content": [{"type": "image"}, {"type": "text", "text": template}]}]
    prompt = processor.apply_chat_template(messages, add_generation_prompt=True, tokenize=False)
    inputs = processor(text=prompt, images=[img], return_tensors="pt").to(model.device)
    prediction = model.generate(
        **inputs,
        max_new_tokens=max_new_tokens,
        do_sample=False,
        # repetition_penalty=1.2,
        pad_token_id=processor.tokenizer.pad_token_id,
        eos_token_id=processor.tokenizer.eos_token_id
    )

    full_pred = processor.decode(prediction[0], skip_special_tokens=False)
    raw_pred = full_pred.split(assistant_token)[-1].replace(processor.tokenizer.eos_token, '').replace(processor.tokenizer.pad_token, '')

    return raw_pred, full_pred


def get_dataset(run_set='all'):

    train_df = pd.read_json(root_dir + f'/experimentation/{domain.lower()}-train.jsonl', lines=True)
    val_df = pd.read_json(root_dir + f'/experimentation/{domain.lower()}-val.jsonl', lines=True)
    test_df = pd.read_json(root_dir + f'/experimentation/{domain.lower()}-test.jsonl', lines=True)

    if run_set == 'all':
        datasets = {'train_df': train_df, 'val_df': val_df, 'test_df': test_df}

    elif run_set == 'train':
        datasets = {'train_df': train_df}

    elif run_set == 'val':
        datasets = {'val_df': val_df}

    elif run_set == 'test':
        datasets = {'test_df': test_df}

    all_unique_images = list(pd.concat(datasets.values())['Image Path'].unique())
    image_cache = {x.replace('data/', ''): load_image(f"{root_dir}{x.replace('data/', '')}") for x in all_unique_images}

    return datasets, image_cache

def create_batch(df, batch_size = 2):

    unique_images = df['Image ID'].unique()
    batches = []

    if batch_size < 1:
        return [df.reset_index()]

        # for _, row in df.iterrows():
        #     batches.append(pd.DataFrame([row]).reset_index())
        # return batches

    remaining_images = list(unique_images)
    while remaining_images:
        current_images = remaining_images[:batch_size]
        batch = df[df['Image ID'].isin(current_images)].reset_index()
        batches.append(batch)
        remaining_images = remaining_images[batch_size:]

    return batches

def get_answers_from_raw_pred(template_id, raw_pred):

      if template_id.startswith('t'):

          return sanitize_pred_label(raw_pred), '', '', -1

      elif template_id == 'rx1':

          return extract_xml_prediction(raw_pred)

      elif template_id.startswith(('v', 'r')):

          return extract_json_prediction(raw_pred)

import copy
from pathlib import Path
import ast
from collections import defaultdict
import pickle

pred_dir = Path(save_dir)

def main(datasets, image_cache, model_name, template_id, domain, run_feedback_loop = True, feedbacks = defaultdict(list), batch_continue = 0, batch_size = 2, early_stop = None, verbose = True):

    for dfname, df in datasets.items():

        print(f"Running {model_name} with on {dfname} set")

        start_time = time.time()

        results = []
        checkpoints = []
        accum_corrections = 0

        max_new_tokens = 1024

        batches = create_batch(df, batch_size)

        for batch_id, batch in tqdm(enumerate(batches), total=len(batches)):

            if batch_id < batch_continue:

                for pred_path in sorted(pred_dir.glob("*.csv")):
                    if run_set+'_df' in str(pred_path) and str(pred_path).split('-')[4][-1] == str(0) and not str(pred_path).endswith('info.csv'):
                        print(f"Loading samples from previous batch: {pred_path}")
                        df = pd.read_csv(pred_path)
                        results.extend(df.to_dict(orient='records'))

                    if run_set+'_df' in str(pred_path) and str(pred_path).split('-')[4][-1] == str(0) and str(pred_path).endswith('info.csv'):
                        print(f"Loading feedbacks from previous batch: {pred_path}")
                        df = pd.read_csv(pred_path)
                        s = df['feedback'].values[-1]
                        inner_dict_str = s.replace("defaultdict(<class 'list'>, ", "").rstrip(")")
                        parsed = ast.literal_eval(inner_dict_str)
                        feedbacks = defaultdict(list, parsed)

                continue

            if batch_id == early_stop:
                break

            print(f"Running Batch {batch_id}")

            log = dict()

            for sample_id, row in tqdm(batch.iterrows(), total=len(batch)):

                domain = row['Domain'].lower()
                filename = row['File']
                image_path = row['Image Path']
                image_id = row['Image ID']
                image_link = row['Image Link']
                rule_key = row['Rule']
                true_label = row['Label']

                raw_pred = ''
                pred_label = 'Unknown'
                pred_reasoning = ''
                pred_explanation = ''
                pred_confidence = -1
                init_raw_pred = ''

                init_pred_label = 'Unknown'
                init_pred_reasoning = ''
                init_pred_explanation = ''
                init_pred_confidence = -1

                if not image_path.lower().endswith(('.jpg', '.jpeg', '.png')):
                    continue

                try:
                    img = image_cache[row['Image Path'].replace('data/', '')]

                    template = get_template(template_id, rule_key, None)

                    raw_pred, full_pred = get_model_outputs(img, template, max_new_tokens)

                    pred_label, pred_reasoning, pred_explanation, pred_confidence = get_answers_from_raw_pred(template_id, raw_pred)


                    init_template = get_template(template_id, rule_key, feedbacks)

                    init_raw_pred, init_full_pred = get_model_outputs(img, init_template, max_new_tokens)

                    init_pred_label, init_pred_reasoning, init_pred_explanation, init_pred_confidence = get_answers_from_raw_pred(template_id, init_raw_pred)

                    log[image_path+rule_key] = {
                        'Domain': domain,
                        'File': filename,
                        'Image ID': image_id,
                        'Image Path': image_path,
                        'Image Link': image_link,
                        'Rule': rule_key,
                        'Label': true_label,

                        'Pred Label': pred_label,
                        'Pred Explanation': pred_explanation,
                        'Pred Confidence': pred_confidence,
                        'Pred Reasoning': pred_reasoning,
                        'Pred Full Response': full_pred,

                        'Pred Init Label': init_pred_label,
                        'Pred Init Explanation': init_pred_explanation,
                        'Pred Init Confidence': init_pred_confidence,
                        'Pred Init Reasoning': init_pred_reasoning,
                        'Pred Init Full Response': init_full_pred,

                        'Pred Revised Label': init_pred_label,
                        'Pred Revised Explanation': init_pred_explanation,
                        'Pred Revised Confidence': init_pred_explanation,
                        'Pred Revised Reasoning': init_pred_explanation,
                        'Pred Revised Full Response': init_full_pred,
                    }


                except Exception as e:
                    print(f"\nPrediction failed for {image_path}: {e}")
                    print(raw_pred)
                    log[image_path+rule_key] = {
                        'Domain': domain,
                        'File': filename,
                        'Image ID': image_id,
                        'Image Path': image_path,
                        'Image Link': image_link,
                        'Rule': rule_key,
                        'Label': true_label,

                        'Pred Label': pred_label,
                        'Pred Explanation': pred_explanation,
                        'Pred Confidence': pred_confidence,
                        'Pred Reasoning': pred_reasoning,
                        'Pred Full Response': full_pred,

                        'Pred Init Label': init_pred_label,
                        'Pred Init Explanation': init_pred_explanation,
                        'Pred Init Confidence': init_pred_confidence,
                        'Pred Init Reasoning': init_pred_reasoning,
                        'Pred Init Full Response': init_full_pred,

                        'Pred Revised Label': init_pred_label,
                        'Pred Revised Explanation': init_pred_explanation,
                        'Pred Revised Confidence': init_pred_explanation,
                        'Pred Revised Reasoning': init_pred_explanation,
                        'Pred Revised Full Response': init_full_pred,
                    }
                    continue

                if run_feedback_loop == True:

                    print(f"Filtering error samples: ...")

                    if init_pred_label == true_label and init_pred_confidence >= 0.99:

                        print("All good! No weak samples to collect feedback from.")

                        results.append(log[image_path+rule_key])

                    else:

                        print(f"Collecting feedback: ...")

                        display(image_cache[image_path.replace('data/', '')])
                        print(f"Sample {sample_id+1}: {image_path}")
                        print(f"Rule: {rule_key}")
                        print(f"Label: {true_label} ; Pred: {init_pred_label}")
                        print(f"Explanation: {init_pred_explanation}")
                        # print(f"Reasoning: \n{row['Pred Init Reasoning']}")
                        print('========================================\n')

                        rule_feedback = input(f"Enter feedback for rule '{rule_key}' (or press Enter to skip): ")

                        tmp_pred_label = init_pred_label

                        rules_updated = None

                        while rule_feedback and tmp_pred_label != true_label and init_pred_confidence < 0.99:

                            feedback_snapshot = copy.deepcopy(feedbacks)
                            feedback_snapshot[rule_key].append(rule_feedback)

                            template = get_template(template_id, rule_key, feedback_snapshot)
                            tmp_raw_pred, tmp_full_pred = get_model_outputs(img, template, max_new_tokens)
                            tmp_pred_label, tmp_pred_reasoning, tmp_pred_explanation, tmp_pred_confidence = get_answers_from_raw_pred(template_id, tmp_raw_pred)

                            log[image_path+rule_key].update({
                                'Pred Tmp Label': tmp_pred_label,
                                'Pred Tmp Explanation': tmp_pred_explanation,
                                'Pred Tmp Confidence': tmp_pred_confidence,
                                'Pred Tmp Reasoning': tmp_pred_reasoning,
                                'Pred Tmp Full Response': tmp_full_pred,
                            })

                            if tmp_pred_label == true_label:
                                accum_corrections += 1
                                print("Nice feedback, the error is corrected!")
                                feedbacks[rule_key].append(rule_feedback)
                                print("Updated Final Feedback: ")
                                augmented_context = "Meta-rules: \n"
                                augmented_context += "\n".join(feedbacks.get('general', ['']))
                                augmented_context += "\n".join(feedbacks.get(rule_key, ['']))
                                rules_updated = rule_key
                                print(augmented_context)

                            else:
                                rule_feedback = input(f"Poor feedback. Please enter a new feedback for rule '{rule_key}' (or press Enter to skip): ")
                                display(image_cache[image_path.replace('data/', '')])
                                print(f"Sample {sample_id+1}: {image_path}")
                                print(f"Rule: {rule_key}")
                                print(f"Label: {true_label} ; Pred: {tmp_pred_label}")
                                print(f"Explanation: {tmp_pred_explanation}")
                                # print(f"Reasoning: \n{tmp_pred_reasoning}")
                                print('========================================\n')

                        results.append(log[image_path+rule_key])

                        print(f"Revising prior samples with updated prompt: ...")

                        tmp_reverse = dict()
                        error_this_round = 0

                        for i, row in tqdm(enumerate(results), total=len(results)):

                            if row['Rule'] != rules_updated:
                                continue

                            if not feedbacks.get(row['Rule']):
                                continue

                            domain = row['Domain'].lower()
                            filename = row['File']
                            image_path = row['Image Path']
                            image_id = row['Image ID']
                            image_link = row['Image Link']
                            rule_key = row['Rule']
                            true_label = row['Label']

                            raw_pred = ''
                            pred_label = 'Unknown'
                            pred_reasoning = ''
                            pred_explanation = ''
                            pred_confidence = -1

                            if not image_path.lower().endswith(('.jpg', '.jpeg', '.png')):
                                continue

                            try:
                                img = image_cache[row['Image Path'].replace('data/', '')]
                                template = get_template(template_id, rule_key, feedbacks)
                                raw_pred, full_pred = get_model_outputs(img, template, max_new_tokens)
                                pred_label, pred_reasoning, pred_explanation, pred_confidence = get_answers_from_raw_pred(template_id, raw_pred)

                                if pred_label != true_label:
                                    error_this_round +=1

                                # else:
                                #     print("Correcting hard sample: ...")

                                #     template = f"""A human reviewer indicated that your previous classification was incorrect. The correct classification should have been: "{true_label}". The reviewer also provided this information: "{feedbacks.get(rule_key)[-1]}". Provide a corrected compliance assessment of the image. {templates.get(template_id)['response_format'].replace('one of "Complied", "Violated", or "Not Applicable"', true_label)}"""
                                #     raw_pred, full_pred = get_model_outputs(img, template, max_new_tokens)
                                #     pred_label, pred_reasoning, pred_explanation, pred_confidence = get_answers_from_raw_pred(template_id, raw_pred)

                                #     if pred_label == true_label:
                                #         num_correct_after_direct_fix +=1

                                tmp_reverse[i] = {
                                    'Pred Revised Label': row['Pred Init Label'],
                                    'Pred Revised Explanation': row['Pred Init Explanation'],
                                    'Pred Revised Confidence': row['Pred Init Confidence'],
                                    'Pred Revised Reasoning': row['Pred Init Reasoning'],
                                    'Pred Revised Full Response': row['Pred Init Full Response'],
                                }

                                results[i].update({
                                    'Pred Revised Label': pred_label,
                                    'Pred Revised Explanation': pred_explanation,
                                    'Pred Revised Confidence': pred_confidence,
                                    'Pred Revised Reasoning': pred_reasoning,
                                    'Pred Revised Full Response': full_pred,
                                })

                                if verbose:

                                    print(f"{i+1}. {row['Image Path']}")
                                    print(f"Rule: {row['Rule']}; Label: {row['Label']}", )
                                    print(f"Initial Pred: {row['Pred Init Label']}  -->  Revised Pred: {pred_label}", f"{'✅' if row['Label'] == pred_label else '❌'}")
                                    print(f"Initial Explanation: {row['Pred Init Explanation']}")
                                    print(f"Revised Explanation: {pred_explanation}")
                                    print('========================================\n')

                            except Exception as e:
                                if verbose:
                                    print(f"\nPrediction failed for {image_path}: {e}")
                                    print(raw_pred)
                                    log[image_path+rule_key].update({
                                        'Pred Revised Label': pred_label,
                                        'Pred Revised Explanation': pred_explanation,
                                        'Pred Revised Confidence': pred_confidence,
                                        'Pred Revised Reasoning': pred_reasoning,
                                        'Pred Revised Full Response': full_pred,
                                    })

                                continue


                        if error_this_round != 0:
                            retry = input(f"Would you like to erase the latest feedback for rule '{rule_key}' and try again later? (y/n): ").strip().lower()

                            if retry == 'y':
                                feedbacks[rule_key] = feedbacks[rule_key][:-1]
                                for update_id, update_items in tmp_reverse.items():
                                    for k, v in update_items.items():
                                        results[update_id][k] = v

                    ground_truth = [x['Label'] for x in results]
                    predictions = [x['Pred Label'] for x in results]
                    revised_predictions = [x['Pred Revised Label'] for x in results]

                    f1_baseline = f1_score(ground_truth, predictions, average='macro')
                    f1_feedback = f1_score(ground_truth, revised_predictions, average='macro')

                    accum_errors = len([1 for x,y in zip(ground_truth, revised_predictions) if x!= y])

                    checkpoints.append({'sample': sample_id, 'feedback': feedbacks,
                        'accum_corrections_made' : accum_corrections,
                        'accum_errors_remaining' : accum_errors,
                        'f1_baselines': f1_baseline, 'f1_feedback': f1_feedback })

                    if verbose:
                        print(f"Sample {sample_id+1} completed")
                        print(f"Accumulated corrections made: {accum_corrections}")
                        print(f"Accumulated errors remaining: {accum_errors}")
                        print(f"Total samples processed: {len(results)}")
                        print(f"F1 Macro (Baselines): {f1_baseline}")
                        print(f"F1 Macro (with Feedback): {f1_feedback}")
                        print('========================================\n')

                else:
                    results.append(log[image_path+rule_key])

        end_time = time.time()

        total_time = end_time - start_time

        mins, secs = divmod(total_time, 60)
        print(f"Total execution time: {int(mins)} min {int(secs)} sec")

        df_results = pd.DataFrame(results)
        # df_results['Pred Revised Label'] = df_results['Pred Revised Label'].fillna(df_results['Pred Init Label'])
        df_results.to_csv(f'{save_dir}/{dfname}-{domain}-{model_name}-{template_id}_batch{batch_id-1}-{RULE_TEMPLATE}-{int(mins)}m{int(secs)}s.csv', index = False)

        print('F1 Macro (Baselines): ', f1_score(df_results['Label'], df_results['Pred Label'], average="macro"))
        print('F1 Macro (with Feedback): ', f1_score(df_results['Label'], df_results['Pred Revised Label'], average="macro"))

        if run_feedback_loop == True:
            df_checkpoints = pd.DataFrame(checkpoints)
            df_checkpoints.to_csv(f'{save_dir}/{dfname}-{domain}-{model_name}-{template_id}_batch{batch_id-1}-{RULE_TEMPLATE}_info.csv', index = False)

            return df_results, df_checkpoints, feedbacks

        return df_results, feedbacks


import torch
from scipy.spatial import distance
import numpy as np

def get_embedding(img, template):
    messages = [{"role": "user", "content": [{"type": "image"}, {"type": "text", "text": template}]}]
    prompt = processor.apply_chat_template(messages, add_generation_prompt=True, tokenize=False)
    inputs = processor(text=prompt, images=[img], return_tensors="pt").to(model.device)

    with torch.no_grad():
        outputs = model(**inputs, output_hidden_states=True, return_dict=True)

    # Take mean over sequence and hidden dimensions
    embedding = outputs.hidden_states[-1].mean(dim=1).cpu()

    return embedding

def run_embeddings(df, image_cache, template_func=None, rule_template = "coded_rules", root_dir=root_dir):
    embedding_cache = {}
    all_unique_images = df['Image Path'].unique()

    for _, row in tqdm(df.iterrows(), total=len(df)):
        clean_path = row['Image Path'].replace('data/', '')

        # If template_func is provided, generate template; else use empty string
        template = get_template(template_id, row['Rule'], rule_template) if template_func else ""
        embedding_cache[clean_path] = get_embedding(image_cache[clean_path], template)

    return embedding_cache


def get_relevant_feedback_by_embedding(feedback_memory, image_embedding, rule_key, top_k=1, threshold=0.0001):

    if rule_key not in feedback_memory or len(feedback_memory[rule_key]) == 0:
        return []

    embeddings = np.stack([entry['embedding'].squeeze().numpy() for entry in feedback_memory[rule_key]])
    dists = distance.cdist([image_embedding.squeeze().numpy()], embeddings, metric='cosine')[0]
    print(dists)

    sorted_indices = np.argsort(dists)
    sorted_dists = dists[sorted_indices]
    feedbacks = [feedback_memory[rule_key][i]["feedback"] for i in sorted_indices]
    valid_feedbacks = [fb for fb, dist in zip(feedbacks, sorted_dists) if dist <= threshold]
    # feedbacks = [entry['feedback'] for entry in feedback_memory[rule_key]]
    # sorted_feedbacks = [feedbacks[i] for i in sorted_indices]

    if len(valid_feedbacks) == 0:
        return []

    return valid_feedbacks[:top_k]

def get_template(template_id, rule_key, retrieved_feedbacks = None, rule_template = RULE_TEMPLATE):

    temp = templates.get(template_id)
    instruction_text = temp.get('instruction_text')
    augmented_context = temp.get('augmented_context')

    if retrieved_feedbacks:
        augmented_context = "\n\nMeta-rules: \n"
        augmented_context += "\n".join(retrieved_feedbacks)

    response_format = temp.get('response_format')

    if rule_template == 'bulletpoints':

        if isinstance(rule_key, list):
            ruleset_text = "Rule Set: \n\n"
            for i, r in enumerate(rule_key, start=1):
                safety_rules = custom_rules[r].strip()
                rule_name = safety_rules.split(':\n')[0].strip()
                rule_description = safety_rules[len(safety_rules.split(':\n')[0])+1:]
                ruleset_text += rule_description
                ruleset_text += "\n\n"

        elif rule_key == 'all':
            ruleset_text = "Rule Set: \n\n"
            for i, (k, v) in enumerate(custom_rules.items(), start = 1):
                safety_rules = v.strip()
                rule_name = safety_rules.split(':\n')[0].strip()
                rule_description = safety_rules[len(safety_rules.split(':\n')[0])+1:]
                ruleset_text += rule_description
                ruleset_text += "\n\n"
        else:
            safety_rules = custom_rules[rule_key].strip()
            rule_name = safety_rules.split(':\n')[0].strip()
            rule_description = safety_rules[len(safety_rules.split(':\n')[0])+1:]
            ruleset_text = f'Rule Set: {rule_description}"'

    elif rule_template == 'bulletpoints-with-header':

        if isinstance(rule_key, list):
          ruleset_text = "Rule Set: \n\n"
          for i, r in enumerate(rule_key, start=1):
              safety_rules = custom_rules[r].strip()
              rule_name = safety_rules.split(':\n')[0].strip()
              rule_description = safety_rules[len(safety_rules.split(':\n')[0])+1:]
              ruleset_text += f'{i}. Rule: "{rule_name}" \nRelevant Sub-Rules: {rule_description}"'
              ruleset_text += "\n\n"

        elif rule_key == 'all':
            ruleset_text = "Rule Set: \n\n"
            for i, (k, v) in enumerate(custom_rules.items(), start = 1):
                safety_rules = v.strip()
                rule_name = safety_rules.split(':\n')[0].strip()
                rule_description = safety_rules[len(safety_rules.split(':\n')[0])+1:]
                ruleset_text += f'{i}. Rule: "{rule_name}" \nRelevant Sub-Rules: {rule_description}"'
                ruleset_text += "\n\n"
        else:
            safety_rules = custom_rules[rule_key].strip()
            rule_name = safety_rules.split(':\n')[0].strip()
            rule_description = safety_rules[len(safety_rules.split(':\n')[0])+1:]
            ruleset_text = f'Rule Set: "{rule_name}" \nRelevant Sub-Rules: {rule_description}"'

    elif rule_template == 'coded-rules':

        if isinstance(rule_key, list):
            ruleset_text = []
            for i, r in enumerate(rule_key, start=1):
                safety_rules = custom_rules[r].strip()
                ruleset_json = parse_ruleset(safety_rules, ruleset_id=f"RS-{i}")
                ruleset_text.append(json_to_ruleset(ruleset_json))

            ruleset_text = '\n\n'.join(ruleset_text).strip()

        elif rule_key == 'all':
            ruleset_text = []
            for i, (k, v) in enumerate(custom_rules.items(), start = 1):
                safety_rules = v.strip()
                ruleset_json = parse_ruleset(safety_rules, ruleset_id=f"RS-{i}")
                ruleset_text.append(json_to_ruleset(ruleset_json))

            ruleset_text = '\n\n'.join(ruleset_text).strip()

        else:
            safety_rules = custom_rules[rule_key].strip()
            ruleset_json = parse_ruleset(safety_rules, ruleset_id="RS-1")
            ruleset_text = json_to_ruleset(ruleset_json).strip()

    return META_PROMPT_TEMPLATE.format(instruction_text=instruction_text, safety_rules=ruleset_text,
                                       augmented_context=augmented_context, response_format=response_format)


def main(datasets, image_cache, model_name, template_id, domain, run_feedback_loop = True, feedback_memory = defaultdict(list), batch_continue = 0, batch_size = 2, early_stop = None, verbose = True):

    for dfname, df in datasets.items():

        print(f"Running {model_name} with on {dfname} set")

        start_time = time.time()

        results = []
        checkpoints = []
        accum_corrections = 0

        max_new_tokens = 1024

        batches = create_batch(df, batch_size)

        for batch_id, batch in tqdm(enumerate(batches), total=len(batches)):

            if batch_id < batch_continue:

                for pred_path in sorted(pred_dir.glob("*.csv")):
                    if run_set+'_df' in str(pred_path) and str(pred_path).split('-')[4][-1] == str(0) and not str(pred_path).endswith('info.csv'):
                        print(f"Loading samples from previous batch: {pred_path}")
                        df = pd.read_csv(pred_path)
                        results.extend(df.to_dict(orient='records'))

                    if run_set+'_df' in str(pred_path) and str(pred_path).split('-')[4][-1] == str(0) and str(pred_path).endswith('info.csv'):
                        print(f"Loading feedbacks from previous batch: {pred_path}")
                        df = pd.read_csv(pred_path)
                        s = df['feedback'].values[-1]
                        inner_dict_str = s.replace("defaultdict(<class 'list'>, ", "").rstrip(")")
                        parsed = ast.literal_eval(inner_dict_str)
                        feedback_memory = defaultdict(list, parsed)

                continue

            if batch_id == early_stop:
                break

            print(f"Running Batch {batch_id}")

            log = dict()

            for sample_id, row in tqdm(batch.iterrows(), total=len(batch)):

                domain = row['Domain'].lower()
                filename = row['File']
                image_path = row['Image Path']
                image_id = row['Image ID']
                image_link = row['Image Link']
                rule_key = row['Rule']
                true_label = row['Label']

                raw_pred = ''
                pred_label = 'Unknown'
                pred_reasoning = ''
                pred_explanation = ''
                pred_confidence = -1
                init_raw_pred = ''

                init_pred_label = 'Unknown'
                init_pred_reasoning = ''
                init_pred_explanation = ''
                init_pred_confidence = -1

                if not image_path.lower().endswith(('.jpg', '.jpeg', '.png')):
                    continue

                try:
                    clean_path = row['Image Path'].replace('data/', '')
                    img = image_cache[clean_path]
                    img_embedding = embedding_cache[clean_path]

                    template = get_template(template_id, rule_key, None)
                    raw_pred, full_pred = get_model_outputs(img, template, max_new_tokens)
                    pred_label, pred_reasoning, pred_explanation, pred_confidence = get_answers_from_raw_pred(template_id, raw_pred)

                    retrieved_feedbacks = get_relevant_feedback_by_embedding(feedback_memory, img_embedding, rule_key)
                    print('Retrieved Feedback: ', retrieved_feedbacks)
                    init_template = get_template(template_id, rule_key, retrieved_feedbacks)
                    init_raw_pred, init_full_pred = get_model_outputs(img, init_template, max_new_tokens)
                    init_pred_label, init_pred_reasoning, init_pred_explanation, init_pred_confidence = get_answers_from_raw_pred(template_id, init_raw_pred)

                    log[image_path+rule_key] = {
                        'Domain': domain,
                        'File': filename,
                        'Image ID': image_id,
                        'Image Path': image_path,
                        'Image Link': image_link,
                        'Rule': rule_key,
                        'Label': true_label,

                        'Pred Label': pred_label,
                        'Pred Explanation': pred_explanation,
                        'Pred Confidence': pred_confidence,
                        'Pred Reasoning': pred_reasoning,
                        'Pred Full Response': full_pred,

                        'Pred Init Label': init_pred_label,
                        'Pred Init Explanation': init_pred_explanation,
                        'Pred Init Confidence': init_pred_confidence,
                        'Pred Init Reasoning': init_pred_reasoning,
                        'Pred Init Full Response': init_full_pred,

                        'Pred Revised Label': init_pred_label,
                        'Pred Revised Explanation': init_pred_explanation,
                        'Pred Revised Confidence': init_pred_explanation,
                        'Pred Revised Reasoning': init_pred_explanation,
                        'Pred Revised Full Response': init_full_pred,
                    }


                except Exception as e:
                    print(f"\nPrediction failed for {image_path}: {e}")
                    print(raw_pred)
                    log[image_path+rule_key] = {
                        'Domain': domain,
                        'File': filename,
                        'Image ID': image_id,
                        'Image Path': image_path,
                        'Image Link': image_link,
                        'Rule': rule_key,
                        'Label': true_label,

                        'Pred Label': pred_label,
                        'Pred Explanation': pred_explanation,
                        'Pred Confidence': pred_confidence,
                        'Pred Reasoning': pred_reasoning,
                        'Pred Full Response': full_pred,

                        'Pred Init Label': init_pred_label,
                        'Pred Init Explanation': init_pred_explanation,
                        'Pred Init Confidence': init_pred_confidence,
                        'Pred Init Reasoning': init_pred_reasoning,
                        'Pred Init Full Response': init_full_pred,

                        'Pred Revised Label': init_pred_label,
                        'Pred Revised Explanation': init_pred_explanation,
                        'Pred Revised Confidence': init_pred_confidence,
                        'Pred Revised Reasoning': init_pred_explanation,
                        'Pred Revised Full Response': init_full_pred,
                    }
                    continue

                if run_feedback_loop == True:

                    print(f"Filtering error samples: ...")

                    if init_pred_label == true_label and init_pred_confidence >=0.9:

                        print("All good! No weak samples to collect feedback from.")

                        display(image_cache[image_path.replace('data/', '')])
                        print(f"Sample {sample_id+1}: {image_path}")
                        print(f"Rule: {rule_key}")
                        # print(f'Response: {init_raw_pred}')
                        print(f"Pred: {init_pred_label}")
                        print(f"Explanation: {init_pred_explanation}")
                        # print(f"Retrieved Feedback: {retrieved_feedbacks}")

                        results.append(log[image_path+rule_key])

                    else:

                        print(f"Collecting feedback: ...")

                        display(image_cache[image_path.replace('data/', '')])
                        print(f"Sample {sample_id+1}: {image_path}")
                        print(f"Rule: {rule_key}")
                        print(f"Label: {true_label} ; Pred: {init_pred_label}")
                        print(f"Explanation: {init_pred_explanation}")
                        print(f"Retrieved Feedback: {retrieved_feedbacks}")
                        # print(f"Reasoning: \n{row['Pred Init Reasoning']}")
                        print('========================================\n')

                        rule_feedback = input(f"Enter feedback for rule '{rule_key}' (or press Enter to skip): ")

                        tmp_pred_label = init_pred_label
                        tmp_pred_confidence = init_pred_confidence

                        rules_updated = None

                        while rule_feedback and (tmp_pred_label != true_label or tmp_pred_confidence < 0.9):

                            feedback_snapshot = copy.deepcopy(feedback_memory)
                            feedback_snapshot[rule_key].append({'embedding': img_embedding, 'feedback': rule_feedback})
                            retrieved_feedbacks = get_relevant_feedback_by_embedding(feedback_snapshot, img_embedding, rule_key)

                            template = get_template(template_id, rule_key, retrieved_feedbacks)
                            tmp_raw_pred, tmp_full_pred = get_model_outputs(img, template, max_new_tokens)
                            tmp_pred_label, tmp_pred_reasoning, tmp_pred_explanation, tmp_pred_confidence = get_answers_from_raw_pred(template_id, tmp_raw_pred)

                            log[image_path+rule_key].update({
                                'Pred Tmp Label': tmp_pred_label,
                                'Pred Tmp Explanation': tmp_pred_explanation,
                                'Pred Tmp Confidence': tmp_pred_confidence,
                                'Pred Tmp Reasoning': tmp_pred_reasoning,
                                'Pred Tmp Full Response': tmp_full_pred,
                            })

                            display(image_cache[image_path.replace('data/', '')])
                            print(f"Sample {sample_id+1}: {image_path}")
                            print(f"Rule: {rule_key}")
                            print(f"Pred: {tmp_pred_label}")
                            print(f"Explanation: {tmp_pred_explanation}")
                            print(f"Confidence: {tmp_pred_confidence}")
                            print(f"Retrieved Feedback: {retrieved_feedbacks}")

                            if tmp_pred_label == true_label and tmp_pred_confidence >= 0.9:
                                accum_corrections += 1
                                print("Nice feedback, the error is corrected!")
                                feedback_memory[rule_key].append({'embedding': img_embedding, 'feedback': rule_feedback})

                                print("\n---------\nUpdated Final Feedback: ")
                                augmented_context = "Meta-rules: \n"
                                retrieved_feedbacks = get_relevant_feedback_by_embedding(feedback_memory, img_embedding, rule_key)
                                augmented_context += "\n".join(retrieved_feedbacks)
                                rules_updated = rule_key
                                print(augmented_context)
                                print('---------')

                                display(image_cache[image_path.replace('data/', '')])
                                print(f"Sample {sample_id+1}: {image_path}")
                                print(f"Rule: {rule_key}")
                                print(f"Label: {true_label} ; Pred: {tmp_pred_label}")
                                print(f"Explanation: {tmp_pred_explanation}")
                                print(f"Retrieved Feedback: {retrieved_feedbacks}")

                                print('========================================\n')

                            else:
                                display(image_cache[image_path.replace('data/', '')])
                                print(f"Sample {sample_id+1}: {image_path}")
                                print(f"Rule: {rule_key}")
                                print(f"Label: {true_label} ; Pred: {tmp_pred_label}")
                                print(f"Explanation: {tmp_pred_explanation}")
                                print(f"Retrieved Feedback: {retrieved_feedbacks}")

                                # print(f"Reasoning: \n{tmp_pred_reasoning}")

                                rule_feedback = input(f"Poor feedback. Please enter a new feedback for rule '{rule_key}' (or press Enter to skip): ")

                                print('========================================\n')

                        results.append(log[image_path+rule_key])

                        print(f"Revising prior samples with updated prompt: ...")

                        tmp_reverse = dict()
                        error_this_round = 0

                        for i, row in tqdm(enumerate(results), total=len(results)):

                            if row['Rule'] != rules_updated:
                                continue

                            if not feedback_memory.get(row['Rule']):
                                continue

                            domain = row['Domain'].lower()
                            filename = row['File']
                            image_path = row['Image Path']
                            image_id = row['Image ID']
                            image_link = row['Image Link']
                            rule_key = row['Rule']
                            true_label = row['Label']

                            raw_pred = ''
                            pred_label = 'Unknown'
                            pred_reasoning = ''
                            pred_explanation = ''
                            pred_confidence = -1

                            if not image_path.lower().endswith(('.jpg', '.jpeg', '.png')):
                                continue

                            try:
                                clean_path = row['Image Path'].replace('data/', '')
                                img = image_cache[clean_path]
                                img_embedding = embedding_cache[clean_path]

                                retrieved_feedbacks = get_relevant_feedback_by_embedding(feedback_memory, img_embedding, rule_key)
                                template = get_template(template_id, rule_key, retrieved_feedbacks)
                                raw_pred, full_pred = get_model_outputs(img, template, max_new_tokens)
                                pred_label, pred_reasoning, pred_explanation, pred_confidence = get_answers_from_raw_pred(template_id, raw_pred)

                                if pred_label != true_label:
                                    error_this_round +=1

                                # else:
                                #     print("Correcting hard sample: ...")

                                #     template = f"""A human reviewer indicated that your previous classification was incorrect. The correct classification should have been: "{true_label}". The reviewer also provided this information: "{feedbacks.get(rule_key)[-1]}". Provide a corrected compliance assessment of the image. {templates.get(template_id)['response_format'].replace('one of "Complied", "Violated", or "Not Applicable"', true_label)}"""
                                #     raw_pred, full_pred = get_model_outputs(img, template, max_new_tokens)
                                #     pred_label, pred_reasoning, pred_explanation, pred_confidence = get_answers_from_raw_pred(template_id, raw_pred)

                                #     if pred_label == true_label:
                                #         num_correct_after_direct_fix +=1

                                tmp_reverse[i] = {
                                    'Pred Revised Label': row['Pred Init Label'],
                                    'Pred Revised Explanation': row['Pred Init Explanation'],
                                    'Pred Revised Confidence': row['Pred Init Confidence'],
                                    'Pred Revised Reasoning': row['Pred Init Reasoning'],
                                    'Pred Revised Full Response': row['Pred Init Full Response'],
                                }

                                results[i].update({
                                    'Pred Revised Label': pred_label,
                                    'Pred Revised Explanation': pred_explanation,
                                    'Pred Revised Confidence': pred_confidence,
                                    'Pred Revised Reasoning': pred_reasoning,
                                    'Pred Revised Full Response': full_pred,
                                })

                                if verbose:

                                    print(f"{i+1}. {row['Image Path']}")
                                    print(f"Rule: {row['Rule']}; Label: {row['Label']}", )
                                    print(f"Initial Pred: {row['Pred Init Label']}  -->  Revised Pred: {pred_label}", f"{'✅' if row['Label'] == pred_label else '❌'}")
                                    print(f"Initial Explanation: {row['Pred Init Explanation']}")
                                    print(f"Revised Explanation: {pred_explanation}")
                                    print('========================================\n')

                            except Exception as e:
                                if verbose:
                                    print(f"\nPrediction failed for {image_path}: {e}")
                                    print(raw_pred)
                                    log[image_path+rule_key].update({
                                        'Pred Revised Label': pred_label,
                                        'Pred Revised Explanation': pred_explanation,
                                        'Pred Revised Confidence': pred_confidence,
                                        'Pred Revised Reasoning': pred_reasoning,
                                        'Pred Revised Full Response': full_pred,
                                    })

                                continue


                        if error_this_round != 0:
                            retry = input(f"Would you like to erase the latest feedback for rule '{rule_key}' and try again later? (y/n): ").strip().lower()

                            if retry == 'y':
                                feedback_memory[rule_key] = feedback_memory[rule_key][:-1]
                                for update_id, update_items in tmp_reverse.items():
                                    for k, v in update_items.items():
                                        results[update_id][k] = v

                    ground_truth = [x['Label'] for x in results]
                    predictions = [x['Pred Label'] for x in results]
                    revised_predictions = [x['Pred Revised Label'] for x in results]

                    f1_baseline = f1_score(ground_truth, predictions, average='macro')
                    f1_feedback = f1_score(ground_truth, revised_predictions, average='macro')

                    accum_errors = len([1 for x,y in zip(ground_truth, revised_predictions) if x!= y])

                    checkpoints.append({'sample': sample_id, 'feedback': feedback_memory,
                        'accum_corrections_made' : accum_corrections,
                        'accum_errors_remaining' : accum_errors,
                        'f1_baselines': f1_baseline, 'f1_feedback': f1_feedback })

                    if verbose:
                        print(f"Sample {sample_id+1} completed")
                        print(f"Accumulated corrections made: {accum_corrections}")
                        print(f"Accumulated errors remaining: {accum_errors}")
                        print(f"Total samples processed: {len(results)}")
                        print(f"F1 Macro (Baselines): {f1_baseline}")
                        print(f"F1 Macro (with Feedback): {f1_feedback}")
                        print('========================================\n')

                else:
                    results.append(log[image_path+rule_key])

        end_time = time.time()

        total_time = end_time - start_time

        mins, secs = divmod(total_time, 60)
        print(f"Total execution time: {int(mins)} min {int(secs)} sec")

        df_results = pd.DataFrame(results)
        # df_results['Pred Revised Label'] = df_results['Pred Revised Label'].fillna(df_results['Pred Init Label'])
        # df_results.to_csv(f'{save_dir}/{dfname}-{domain}-{model_name}-{template_id}_batch{batch_id-1}-{RULE_TEMPLATE}-{int(mins)}m{int(secs)}s.csv', index = False)

        print('F1 Macro (Baselines): ', f1_score(df_results['Label'], df_results['Pred Label'], average="macro"))
        print('F1 Macro (with Feedback): ', f1_score(df_results['Label'], df_results['Pred Revised Label'], average="macro"))

        if run_feedback_loop == True:
            df_checkpoints = pd.DataFrame(checkpoints)
            df_checkpoints.to_csv(f'{save_dir}/{dfname}-{domain}-{model_name}-{template_id}_batch{batch_id-1}-{RULE_TEMPLATE}_info.csv', index = False)
            # with open(f"{save_dir}/{dfname}-{domain}-{model_name}-{template_id}_batch{batch_id-1}-{RULE_TEMPLATE}_feedback.pkl", "wb") as f:
            #     pickle.dump(feedback_memory, f)

            return df_results, df_checkpoints, feedback_memory

        return df_results, feedback_memory
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
run_set = 'train'
datasets, image_cache = get_dataset(run_set)
embedding_cache = run_embeddings(datasets[f'{run_set}_df'], image_cache)
# datasets[f'{run_set}_df'] = datasets[f'{run_set}_df'][(datasets[f'{run_set}_df']['Image Path'].str.contains('data/processed_images/construction/Protective_Equipment_1')) & (datasets[f'{run_set}_df']['Rule'] == 'Protective Equipment')]
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   0%|          | 0/1500 [00:00<?, ?it/s]

# %% [markdown]
# Run Batch 0

# %%
run_feedback_loop = True
run_set = 'train'
datasets, image_cache = get_dataset(run_set)
embedding_cache = run_embeddings(datasets[f'{run_set}_df'], image_cache)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   0%|          | 0/1500 [00:00<?, ?it/s]

# %%
init_feedbacks = defaultdict(list) # empty
batch_size = 1 # e.g. run 5 rules by sampling 1 unique image ids from 10 binary rule files = 50 samples

batch_continue = 0 # batch id to start/continue from
early_stop = 1 # e.g. stop before batch_id = 1

df_results, df_checkpoints, feedbacks = main(datasets, image_cache, model_name, template_id, domain, run_feedback_loop, init_feedbacks, batch_continue, batch_size, early_stop)
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Running llava-finetuned with on train_df set
#   0%|          | 0/30 [00:00<?, ?it/s]
# Running Batch 0
#   0%|          | 0/50 [00:00<?, ?it/s]
# Retrieved Feedback:  []
# Filtering error samples: ...
# Collecting feedback: ...
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=336x336>
# Sample 1: data/processed_images/traffic/Driving_Distraction_0/0000002.jpg
# Rule: Driving Distraction
# Label: Complied ; Pred: Not Applicable
# Explanation: The image shows a man driving a car, but there is no indication that he is using a cell phone or engaging in any other activity that would distract him from driving. Therefore, the rule is not applicable.
# Retrieved Feedback: []
# ========================================
#
# Enter feedback for rule 'Driving Distraction' (or press Enter to skip): If the driver is focused on driving, the rule is complied with.
# [1.11022302e-16]
# Nice feedback, the error is corrected!
#
# ---------
# Updated Final Feedback:
# [1.11022302e-16]
# Meta-rules:
# If the driver is focused on driving, the rule is complied with.
# ---------
# Revising prior samples with updated prompt: ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# [1.11022302e-16]
# 1. data/processed_images/traffic/Driving_Distraction_0/0000002.jpg
# Rule: Driving Distraction; Label: Complied
# Initial Pred: Not Applicable  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows a man driving a car, but there is no indication that he is using a cell phone or engaging in any other activity that would distract him from driving. Therefore, the rule is not applicable.
# Revised Explanation: The driver is not using a cell phone or engaging in any other distracting activity. He is focused on driving and has proper control of the vehicle. Therefore, the rule is complied with.
# ========================================
#
# Sample 1 completed
# Accumulated corrections made: 1
# Accumulated errors remaining: 0
# Total samples processed: 1
# F1 Macro (Baselines): 0.0
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 2 completed
# Accumulated corrections made: 1
# Accumulated errors remaining: 0
# Total samples processed: 2
# F1 Macro (Baselines): 0.3333333333333333
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 3 completed
# Accumulated corrections made: 1
# Accumulated errors remaining: 0
# Total samples processed: 3
# F1 Macro (Baselines): 0.4
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 4 completed
# Accumulated corrections made: 1
# Accumulated errors remaining: 0
# Total samples processed: 4
# F1 Macro (Baselines): 0.42857142857142855
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 5 completed
# Accumulated corrections made: 1
# Accumulated errors remaining: 0
# Total samples processed: 5
# F1 Macro (Baselines): 0.4444444444444444
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00027888]
# Retrieved Feedback:  ['If the driver is focused on driving, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 6 completed
# Accumulated corrections made: 1
# Accumulated errors remaining: 0
# Total samples processed: 6
# F1 Macro (Baselines): 0.6296296296296297
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 7 completed
# Accumulated corrections made: 1
# Accumulated errors remaining: 0
# Total samples processed: 7
# F1 Macro (Baselines): 0.6363636363636364
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 8 completed
# Accumulated corrections made: 1
# Accumulated errors remaining: 0
# Total samples processed: 8
# F1 Macro (Baselines): 0.6410256410256411
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 9 completed
# Accumulated corrections made: 1
# Accumulated errors remaining: 0
# Total samples processed: 9
# F1 Macro (Baselines): 0.6444444444444445
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 10 completed
# Accumulated corrections made: 1
# Accumulated errors remaining: 0
# Total samples processed: 10
# F1 Macro (Baselines): 0.6470588235294118
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00030971]
# Retrieved Feedback:  ['If the driver is focused on driving, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 11 completed
# Accumulated corrections made: 1
# Accumulated errors remaining: 0
# Total samples processed: 11
# F1 Macro (Baselines): 0.6491228070175438
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# Collecting feedback: ...
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=336x336>
# Sample 12: data/processed_images/traffic/Pedestrian_Crossing_0/0000002.jpg
# Rule: Pedestrian Crossing
# Label: Complied ; Pred: Violated
# Explanation: The image shows a group of people crossing the street at a crosswalk, and a car is driving towards them. This indicates that the pedestrians are not following the rule of crossing the road by the shortest safe route. Additionally, the pedestrians are not following the rule of not causing a traffic hazard by moving into the path of a driver. The confidence is 0.95 as the rule violation is clear and unambiguous.
# Retrieved Feedback: []
# ========================================
#
# Enter feedback for rule 'Pedestrian Crossing' (or press Enter to skip): If the pedestrians are crossing at a crosswalk, the rule is complied with.
# [0.]
# Nice feedback, the error is corrected!
#
# ---------
# Updated Final Feedback:
# [0.]
# Meta-rules:
# If the pedestrians are crossing at a crosswalk, the rule is complied with.
# ---------
# Revising prior samples with updated prompt: ...
#   0%|          | 0/12 [00:00<?, ?it/s]
# [0.00030971]
# 2. data/processed_images/traffic/Driving_Distraction_0/0000002.jpg
# Rule: Pedestrian Crossing; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a man driving a car, not a pedestrian crossing a road. Therefore, the rules do not apply.
# Revised Explanation: The image shows a man driving a car, not a pedestrian crossing a road. Therefore, the rules do not apply in this scenario.
# ========================================
#
# [0.00028732]
# 7. data/processed_images/traffic/Driving_Distraction_1/0000002.jpg
# Rule: Pedestrian Crossing; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a woman driving a car, not a pedestrian crossing a road. The rules do not apply to this scenario.
# Revised Explanation: The image shows a woman driving a car, not a pedestrian crossing a road. The rules do not apply to this scenario.
# ========================================
#
# [0.]
# 12. data/processed_images/traffic/Pedestrian_Crossing_0/0000002.jpg
# Rule: Pedestrian Crossing; Label: Complied
# Initial Pred: Violated  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows a group of people crossing the street at a crosswalk, and a car is driving towards them. This indicates that the pedestrians are not following the rule of crossing the road by the shortest safe route. Additionally, the pedestrians are not following the rule of not causing a traffic hazard by moving into the path of a driver. The confidence is 0.95 as the rule violation is clear and unambiguous.
# Revised Explanation: The pedestrians are crossing the road at a crosswalk, which is the shortest safe route. They are not staying on the road longer than necessary to cross the road safely. Therefore, the rule is complied with.
# ========================================
#
# Sample 12 completed
# Accumulated corrections made: 2
# Accumulated errors remaining: 0
# Total samples processed: 12
# F1 Macro (Baselines): 0.5380116959064327
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 13 completed
# Accumulated corrections made: 2
# Accumulated errors remaining: 0
# Total samples processed: 13
# F1 Macro (Baselines): 0.7046783625730993
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# Collecting feedback: ...
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=336x336>
# Sample 14: data/processed_images/traffic/Pedestrian_Crossing_0/0000002.jpg
# Rule: Traffic Rules
# Label: Complied ; Pred: Violated
# Explanation: The image shows a red car driving on a crosswalk, which is a violation of the rule that states a driver must not drive in a pedestrian crossing. The car is also driving on a crosswalk with people walking, which further emphasizes the violation of the rule.
# Retrieved Feedback: []
# ========================================
#
# Enter feedback for rule 'Traffic Rules' (or press Enter to skip): If the vehicles stop before a crosswalk and give way to the pedestrians at the crossing, the rule is complied with.
# [0.]
# Nice feedback, the error is corrected!
#
# ---------
# Updated Final Feedback:
# [0.]
# Meta-rules:
# If the vehicles stop before a crosswalk and give way to the pedestrians at the crossing, the rule is complied with.
# ---------
# Revising prior samples with updated prompt: ...
#   0%|          | 0/14 [00:00<?, ?it/s]
# [0.00030971]
# 4. data/processed_images/traffic/Driving_Distraction_0/0000002.jpg
# Rule: Traffic Rules; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a man driving a car on a road. The rules provided are related to pedestrian crossings, children's crossings, and traffic lights. Since the man is driving a car and not a pedestrian, the rules provided are not applicable to this scenario.
# Revised Explanation: The image shows a man driving a car, but there are no pedestrians or crosswalks visible. Therefore, the rules related to pedestrians and crosswalks do not apply in this scenario.
# ========================================
#
# [0.00028732]
# 9. data/processed_images/traffic/Driving_Distraction_1/0000002.jpg
# Rule: Traffic Rules; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a woman driving a car. The rules provided are related to pedestrians, children's crossings, and traffic lights. Since the woman is driving a car and not a pedestrian, the rules are not applicable in this scenario.
# Revised Explanation: The image shows a woman driving a car. The rules provided are related to pedestrians and crosswalks. Since the woman is driving, the rules are not applicable in this scenario.
# ========================================
#
# [0.]
# 14. data/processed_images/traffic/Pedestrian_Crossing_0/0000002.jpg
# Rule: Traffic Rules; Label: Complied
# Initial Pred: Violated  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows a red car driving on a crosswalk, which is a violation of the rule that states a driver must not drive in a pedestrian crossing. The car is also driving on a crosswalk with people walking, which further emphasizes the violation of the rule.
# Revised Explanation: The image shows a group of people crossing the street at a crosswalk. A car is stopped at the crosswalk, and the pedestrians are giving way to the car. This scenario complies with the rule that a driver must give way to any pedestrian on or entering a pedestrian crossing.
# ========================================
#
# Sample 14 completed
# Accumulated corrections made: 3
# Accumulated errors remaining: 0
# Total samples processed: 14
# F1 Macro (Baselines): 0.6157894736842106
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 15 completed
# Accumulated corrections made: 3
# Accumulated errors remaining: 0
# Total samples processed: 15
# F1 Macro (Baselines): 0.6174603174603175
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00050381]
# Retrieved Feedback:  ['If the driver is focused on driving, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 16 completed
# Accumulated corrections made: 3
# Accumulated errors remaining: 0
# Total samples processed: 16
# F1 Macro (Baselines): 0.618840579710145
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00042202]
# Retrieved Feedback:  ['If the pedestrians are crossing at a crosswalk, the rule is complied with.']
# Filtering error samples: ...
# Collecting feedback: ...
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=336x336>
# Sample 17: data/processed_images/traffic/Pedestrian_Crossing_1/0000002.jpg
# Rule: Pedestrian Crossing
# Label: Violated ; Pred: Complied
# Explanation: The pedestrians are crossing the road at a crosswalk, which is the shortest safe route. They are not causing a traffic hazard or obstruction. Therefore, the rule is complied with.
# Retrieved Feedback: ['If the pedestrians are crossing at a crosswalk, the rule is complied with.']
# ========================================
#
# Enter feedback for rule 'Pedestrian Crossing' (or press Enter to skip): If the pedestrian is crossing at a red light, it is illegal, the pedestrian should wait for green light, the rule is violated.
# [0.00042202 0.        ]
# Nice feedback, the error is corrected!
#
# ---------
# Updated Final Feedback:
# [0.00042202 0.        ]
# Meta-rules:
# If the pedestrian is crossing at a red light, it is illegal, the pedestrian should wait for green light, the rule is violated.
# ---------
# Revising prior samples with updated prompt: ...
#   0%|          | 0/17 [00:00<?, ?it/s]
# [0.00030971 0.00050381]
# 2. data/processed_images/traffic/Driving_Distraction_0/0000002.jpg
# Rule: Pedestrian Crossing; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a man driving a car, not a pedestrian crossing a road. Therefore, the rules do not apply.
# Revised Explanation: The image shows a man driving a car, not a pedestrian crossing a road. Therefore, the rules do not apply in this scenario.
# ========================================
#
# [0.00028732 0.00032891]
# 7. data/processed_images/traffic/Driving_Distraction_1/0000002.jpg
# Rule: Pedestrian Crossing; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a woman driving a car, not a pedestrian crossing a road. The rules do not apply to this scenario.
# Revised Explanation: The image shows a woman driving a car, not a pedestrian crossing a road. The rules do not apply to this scenario.
# ========================================
#
# [0.         0.00042202]
# 12. data/processed_images/traffic/Pedestrian_Crossing_0/0000002.jpg
# Rule: Pedestrian Crossing; Label: Complied
# Initial Pred: Violated  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows a group of people crossing the street at a crosswalk, and a car is driving towards them. This indicates that the pedestrians are not following the rule of crossing the road by the shortest safe route. Additionally, the pedestrians are not following the rule of not causing a traffic hazard by moving into the path of a driver. The confidence is 0.95 as the rule violation is clear and unambiguous.
# Revised Explanation: The pedestrians are crossing the road at a crosswalk, which is the shortest safe route. They are not staying on the road longer than necessary to cross the road safely. Therefore, the rule is complied with.
# ========================================
#
# [0.00042202 0.        ]
# 17. data/processed_images/traffic/Pedestrian_Crossing_1/0000002.jpg
# Rule: Pedestrian Crossing; Label: Violated
# Initial Pred: Complied  -->  Revised Pred: Violated ✅
# Initial Explanation: The pedestrians are crossing the road at a crosswalk, which is the shortest safe route. They are not causing a traffic hazard or obstruction. Therefore, the rule is complied with.
# Revised Explanation: The pedestrians are crossing the road at a red light, which is illegal. They should wait for the green light to cross the road safely. Therefore, the rule is violated.
# ========================================
#
# Sample 17 completed
# Accumulated corrections made: 4
# Accumulated errors remaining: 0
# Total samples processed: 17
# F1 Macro (Baselines): 0.5632850241545894
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 18 completed
# Accumulated corrections made: 4
# Accumulated errors remaining: 0
# Total samples processed: 18
# F1 Macro (Baselines): 0.618840579710145
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00042202]
# Retrieved Feedback:  ['If the vehicles stop before a crosswalk and give way to the pedestrians at the crossing, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 19 completed
# Accumulated corrections made: 4
# Accumulated errors remaining: 0
# Total samples processed: 19
# F1 Macro (Baselines): 0.6521739130434782
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 20 completed
# Accumulated corrections made: 4
# Accumulated errors remaining: 0
# Total samples processed: 20
# F1 Macro (Baselines): 0.6533333333333333
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00037317]
# Retrieved Feedback:  ['If the driver is focused on driving, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 21 completed
# Accumulated corrections made: 4
# Accumulated errors remaining: 0
# Total samples processed: 21
# F1 Macro (Baselines): 0.6543209876543209
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00037061 0.00032563]
# Retrieved Feedback:  ['If the pedestrian is crossing at a red light, it is illegal, the pedestrian should wait for green light, the rule is violated.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 22 completed
# Accumulated corrections made: 4
# Accumulated errors remaining: 0
# Total samples processed: 22
# F1 Macro (Baselines): 0.6551724137931035
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 23 completed
# Accumulated corrections made: 4
# Accumulated errors remaining: 0
# Total samples processed: 23
# F1 Macro (Baselines): 0.6773946360153257
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00037061]
# Retrieved Feedback:  ['If the vehicles stop before a crosswalk and give way to the pedestrians at the crossing, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 24 completed
# Accumulated corrections made: 4
# Accumulated errors remaining: 0
# Total samples processed: 24
# F1 Macro (Baselines): 0.6380783966990864
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# Collecting feedback: ...
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=336x336>
# Sample 25: data/processed_images/traffic/Road_Condition_0/0000002.jpg
# Rule: Vehicle Load
# Label: Complied ; Pred: Not Applicable
# Explanation: The image shows a car driving on a road with a truck in the background. There are no large indivisible items being carried by the vehicles. The vehicles are not overloaded, and the load is properly restrained. Therefore, the rules do not apply to this scenario.
# Retrieved Feedback: []
# ========================================
#
# Enter feedback for rule 'Vehicle Load' (or press Enter to skip): If the truck is not overloading, the rule is complied with.
# [1.11022302e-16]
# Nice feedback, the error is corrected!
#
# ---------
# Updated Final Feedback:
# [1.11022302e-16]
# Meta-rules:
# If the truck is not overloading, the rule is complied with.
# ---------
# Revising prior samples with updated prompt: ...
#   0%|          | 0/25 [00:00<?, ?it/s]
# [0.00037317]
# 5. data/processed_images/traffic/Driving_Distraction_0/0000002.jpg
# Rule: Vehicle Load; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a man driving a car, but there is no indication of a large indivisible item being carried. Therefore, the rule does not apply.
# Revised Explanation: The image shows a man driving a car, but there is no indication of a large indivisible item being carried. Therefore, the rule is not applicable.
# ========================================
#
# [0.00038406]
# 10. data/processed_images/traffic/Driving_Distraction_1/0000002.jpg
# Rule: Vehicle Load; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a woman driving a car, but there is no indication of a large indivisible item being carried. Therefore, the rule does not apply.
# Revised Explanation: The image shows a woman driving a car, but there is no indication of a large indivisible item being carried. Therefore, the rule is not applicable.
# ========================================
#
# [0.00037061]
# 15. data/processed_images/traffic/Pedestrian_Crossing_0/0000002.jpg
# Rule: Vehicle Load; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a group of people crossing a street at a crosswalk. There are no vehicles carrying goods or large indivisible items. The load restraint requirement is not applicable in this scenario.
# Revised Explanation: The image shows a group of people crossing a street at a crosswalk. There are no vehicles or loads visible in the image. Therefore, the rules are not applicable.
# ========================================
#
# [0.00032563]
# 20. data/processed_images/traffic/Pedestrian_Crossing_1/0000002.jpg
# Rule: Vehicle Load; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a group of people walking on a street with cars and traffic lights. There are no large indivisible items being carried by the vehicles, and the load is properly restrained. Therefore, the rules RS-1.1 and RS-1.2 do not apply in this scenario.
# Revised Explanation: The image shows a truck carrying a large indivisible item and a small item. Therefore, the rule is not applicable.
# ========================================
#
# [1.11022302e-16]
# 25. data/processed_images/traffic/Road_Condition_0/0000002.jpg
# Rule: Vehicle Load; Label: Complied
# Initial Pred: Not Applicable  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows a car driving on a road with a truck in the background. There are no large indivisible items being carried by the vehicles. The vehicles are not overloaded, and the load is properly restrained. Therefore, the rules do not apply to this scenario.
# Revised Explanation: The truck is carrying a large indivisible item, which is a compliance with the rule. The truck is also carrying a passenger, which is a compliance with the rule. The truck is not overloading, which is a compliance with the rule.
# ========================================
#
# Sample 25 completed
# Accumulated corrections made: 5
# Accumulated errors remaining: 0
# Total samples processed: 25
# F1 Macro (Baselines): 0.6126984126984126
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00048256]
# Retrieved Feedback:  ['If the driver is focused on driving, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 26 completed
# Accumulated corrections made: 5
# Accumulated errors remaining: 0
# Total samples processed: 26
# F1 Macro (Baselines): 0.6140873015873015
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00039428 0.00047334]
# Retrieved Feedback:  ['If the pedestrians are crossing at a crosswalk, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 27 completed
# Accumulated corrections made: 5
# Accumulated errors remaining: 0
# Total samples processed: 27
# F1 Macro (Baselines): 0.6153127917833799
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 28 completed
# Accumulated corrections made: 5
# Accumulated errors remaining: 0
# Total samples processed: 28
# F1 Macro (Baselines): 0.6708683473389355
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00039428]
# Retrieved Feedback:  ['If the vehicles stop before a crosswalk and give way to the pedestrians at the crossing, the rule is complied with.']
# Filtering error samples: ...
# Collecting feedback: ...
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=336x336>
# Sample 29: data/processed_images/traffic/Road_Condition_1/0000002.jpg
# Rule: Traffic Rules
# Label: Not Applicable ; Pred: Violated
# Explanation: The image shows a fallen power line on the road, which indicates that the rule is not being followed. The rule states that a driver must not stop in an emergency stopping lane. The presence of the fallen power line suggests that there was an emergency that required immediate attention, and the driver did not follow the rule by stopping in the emergency stopping lane.
# Retrieved Feedback: ['If the vehicles stop before a crosswalk and give way to the pedestrians at the crossing, the rule is complied with.']
# ========================================
#
# Enter feedback for rule 'Traffic Rules' (or press Enter to skip): If there is no cars or pedestrians to assess traffic rules, the rule is not applicable.
# [3.94281942e-04 1.11022302e-16]
# Nice feedback, the error is corrected!
#
# ---------
# Updated Final Feedback:
# [3.94281942e-04 1.11022302e-16]
# Meta-rules:
# If there is no cars or pedestrians to assess traffic rules, the rule is not applicable.
# ---------
# Revising prior samples with updated prompt: ...
#   0%|          | 0/29 [00:00<?, ?it/s]
# [0.00030971 0.00048256]
# 4. data/processed_images/traffic/Driving_Distraction_0/0000002.jpg
# Rule: Traffic Rules; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a man driving a car on a road. The rules provided are related to pedestrian crossings, children's crossings, and traffic lights. Since the man is driving a car and not a pedestrian, the rules provided are not applicable to this scenario.
# Revised Explanation: The image shows a man driving a car, but there are no pedestrians or crosswalks visible. Therefore, the rules related to pedestrians and crosswalks do not apply in this scenario.
# ========================================
#
# [0.00028732 0.0004211 ]
# 9. data/processed_images/traffic/Driving_Distraction_1/0000002.jpg
# Rule: Traffic Rules; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a woman driving a car. The rules provided are related to pedestrians, children's crossings, and traffic lights. Since the woman is driving a car and not a pedestrian, the rules are not applicable in this scenario.
# Revised Explanation: The image shows a woman driving a car. The rules provided are related to pedestrians and crosswalks. Since the woman is driving, the rules are not applicable in this scenario.
# ========================================
#
# [0.         0.00039428]
# 14. data/processed_images/traffic/Pedestrian_Crossing_0/0000002.jpg
# Rule: Traffic Rules; Label: Complied
# Initial Pred: Violated  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows a red car driving on a crosswalk, which is a violation of the rule that states a driver must not drive in a pedestrian crossing. The car is also driving on a crosswalk with people walking, which further emphasizes the violation of the rule.
# Revised Explanation: The image shows a group of people crossing the street at a crosswalk. A car is stopped at the crosswalk, and the pedestrians are giving way to the car. This scenario complies with the rule that a driver must give way to any pedestrian on or entering a pedestrian crossing.
# ========================================
#
# [0.00042202 0.00047334]
# 19. data/processed_images/traffic/Pedestrian_Crossing_1/0000002.jpg
# Rule: Traffic Rules; Label: Complied
# Initial Pred: Complied  -->  Revised Pred: Complied ✅
# Initial Explanation: The vehicles are stopping before the crosswalk and giving way to the pedestrians at the crossing, which is a compliance with the rule.
# Revised Explanation: The vehicles are stopping before the crosswalk and giving way to the pedestrians at the crossing, which is a compliance with the rule.
# ========================================
#
# [0.00037061 0.0004539 ]
# 24. data/processed_images/traffic/Road_Condition_0/0000002.jpg
# Rule: Traffic Rules; Label: Complied
# Initial Pred: Complied  -->  Revised Pred: Complied ✅
# Initial Explanation: The vehicles are stopping before the crosswalk and giving way to the pedestrians at the crossing, which is complying with the rule.
# Revised Explanation: The vehicles are stopping before the crosswalk and giving way to the pedestrians at the crossing, which is complying with the rule.
# ========================================
#
# [3.94281942e-04 1.11022302e-16]
# 29. data/processed_images/traffic/Road_Condition_1/0000002.jpg
# Rule: Traffic Rules; Label: Not Applicable
# Initial Pred: Violated  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a fallen power line on the road, which indicates that the rule is not being followed. The rule states that a driver must not stop in an emergency stopping lane. The presence of the fallen power line suggests that there was an emergency that required immediate attention, and the driver did not follow the rule by stopping in the emergency stopping lane.
# Revised Explanation: The image shows a fallen power line and a telephone pole. There are no cars or pedestrians in the scene. Therefore, the rules RS-1.1, RS-1.2, RS-1.3, RS-1.4, RS-1.5, RS-1.6, RS-1.7, RS-1.8, RS-1.9, and RS-1.10 are not applicable in this scenario.
# ========================================
#
# Sample 29 completed
# Accumulated corrections made: 6
# Accumulated errors remaining: 0
# Total samples processed: 29
# F1 Macro (Baselines): 0.6433862433862434
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.0004539]
# Retrieved Feedback:  ['If the truck is not overloading, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 30 completed
# Accumulated corrections made: 6
# Accumulated errors remaining: 0
# Total samples processed: 30
# F1 Macro (Baselines): 0.644930644930645
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00041849]
# Retrieved Feedback:  ['If the driver is focused on driving, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 31 completed
# Accumulated corrections made: 6
# Accumulated errors remaining: 0
# Total samples processed: 31
# F1 Macro (Baselines): 0.6463166463166463
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00031083 0.00033318]
# Retrieved Feedback:  ['If the pedestrians are crossing at a crosswalk, the rule is complied with.']
# Filtering error samples: ...
# Collecting feedback: ...
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=336x336>
# Sample 32: data/processed_images/traffic/Traffic_Rules_0/0000002.jpg
# Rule: Pedestrian Crossing
# Label: Violated ; Pred: Complied
# Explanation: The pedestrians are crossing the road at a crosswalk, which is the shortest safe route. They are not causing a traffic hazard or obstruction. Therefore, the rule is complied with.
# Retrieved Feedback: ['If the pedestrians are crossing at a crosswalk, the rule is complied with.']
# ========================================
#
# Enter feedback for rule 'Pedestrian Crossing' (or press Enter to skip): If the pedestrian is crossing at a red light, it is illegal, the pedestrian should wait for green light, the rule is violated.
# [3.10826698e-04 3.33176639e-04 1.11022302e-16]
# Nice feedback, the error is corrected!
#
# ---------
# Updated Final Feedback:
# [3.10826698e-04 3.33176639e-04 1.11022302e-16]
# Meta-rules:
# If the pedestrian is crossing at a red light, it is illegal, the pedestrian should wait for green light, the rule is violated.
# ---------
# Revising prior samples with updated prompt: ...
#   0%|          | 0/32 [00:00<?, ?it/s]
# [0.00030971 0.00050381 0.00041849]
# 2. data/processed_images/traffic/Driving_Distraction_0/0000002.jpg
# Rule: Pedestrian Crossing; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a man driving a car, not a pedestrian crossing a road. Therefore, the rules do not apply.
# Revised Explanation: The image shows a man driving a car, not a pedestrian crossing a road. Therefore, the rules do not apply in this scenario.
# ========================================
#
# [0.00028732 0.00032891 0.00042152]
# 7. data/processed_images/traffic/Driving_Distraction_1/0000002.jpg
# Rule: Pedestrian Crossing; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a woman driving a car, not a pedestrian crossing a road. The rules do not apply to this scenario.
# Revised Explanation: The image shows a woman driving a car, not a pedestrian crossing a road. The rules do not apply to this scenario.
# ========================================
#
# [0.         0.00042202 0.00031083]
# 12. data/processed_images/traffic/Pedestrian_Crossing_0/0000002.jpg
# Rule: Pedestrian Crossing; Label: Complied
# Initial Pred: Violated  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows a group of people crossing the street at a crosswalk, and a car is driving towards them. This indicates that the pedestrians are not following the rule of crossing the road by the shortest safe route. Additionally, the pedestrians are not following the rule of not causing a traffic hazard by moving into the path of a driver. The confidence is 0.95 as the rule violation is clear and unambiguous.
# Revised Explanation: The pedestrians are crossing the road at a crosswalk, which is the shortest safe route. They are not staying on the road longer than necessary to cross the road safely. Therefore, the rule is complied with.
# ========================================
#
# [0.00042202 0.         0.00033318]
# 17. data/processed_images/traffic/Pedestrian_Crossing_1/0000002.jpg
# Rule: Pedestrian Crossing; Label: Violated
# Initial Pred: Complied  -->  Revised Pred: Violated ✅
# Initial Explanation: The pedestrians are crossing the road at a crosswalk, which is the shortest safe route. They are not causing a traffic hazard or obstruction. Therefore, the rule is complied with.
# Revised Explanation: The pedestrians are crossing the road at a red light, which is illegal. They should wait for the green light to cross the road safely. Therefore, the rule is violated.
# ========================================
#
# [0.00037061 0.00032563 0.00038589]
# 22. data/processed_images/traffic/Road_Condition_0/0000002.jpg
# Rule: Pedestrian Crossing; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a car driving on a road with a pedestrian crossing sign. There are no pedestrians visible in the image. Therefore, the rules do not apply in this scenario.
# Revised Explanation: The image shows a car driving on a road with a pedestrian crossing sign. There are no pedestrians visible in the image. Therefore, the rules do not apply in this scenario.
# ========================================
#
# [0.00039428 0.00047334 0.00054788]
# 27. data/processed_images/traffic/Road_Condition_1/0000002.jpg
# Rule: Pedestrian Crossing; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a fallen power line and a car on the road. There are no pedestrians visible in the image. Therefore, the rules do not apply in this scenario.
# Revised Explanation: The image shows a fallen power line and a car on the road. There are no pedestrians visible in the image. Therefore, the rules do not apply in this scenario.
# ========================================
#
# [3.10826698e-04 3.33176639e-04 1.11022302e-16]
# 32. data/processed_images/traffic/Traffic_Rules_0/0000002.jpg
# Rule: Pedestrian Crossing; Label: Violated
# Initial Pred: Complied  -->  Revised Pred: Violated ✅
# Initial Explanation: The pedestrians are crossing the road at a crosswalk, which is the shortest safe route. They are not causing a traffic hazard or obstruction. Therefore, the rule is complied with.
# Revised Explanation: The pedestrians are crossing the street at a red light, which is illegal. They should wait for the green light to cross the road safely. Therefore, the rule is violated.
# ========================================
#
# Sample 32 completed
# Accumulated corrections made: 7
# Accumulated errors remaining: 0
# Total samples processed: 32
# F1 Macro (Baselines): 0.6188034188034188
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 33 completed
# Accumulated corrections made: 7
# Accumulated errors remaining: 0
# Total samples processed: 33
# F1 Macro (Baselines): 0.63710407239819
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00031083 0.00054788]
# Retrieved Feedback:  ['If the vehicles stop before a crosswalk and give way to the pedestrians at the crossing, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 34 completed
# Accumulated corrections made: 7
# Accumulated errors remaining: 0
# Total samples processed: 34
# F1 Macro (Baselines): 0.6140896140896142
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00038589]
# Retrieved Feedback:  ['If the truck is not overloading, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 35 completed
# Accumulated corrections made: 7
# Accumulated errors remaining: 0
# Total samples processed: 35
# F1 Macro (Baselines): 0.6153403958282008
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00044136]
# Retrieved Feedback:  ['If the driver is focused on driving, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 36 completed
# Accumulated corrections made: 7
# Accumulated errors remaining: 0
# Total samples processed: 36
# F1 Macro (Baselines): 0.6164748257771514
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00033145 0.00030505 0.00055382]
# Retrieved Feedback:  ['If the pedestrian is crossing at a red light, it is illegal, the pedestrian should wait for green light, the rule is violated.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 37 completed
# Accumulated corrections made: 7
# Accumulated errors remaining: 0
# Total samples processed: 37
# F1 Macro (Baselines): 0.6175084175084176
# F1 Macro (with Feedback): 1.0
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 38 completed
# Accumulated corrections made: 7
# Accumulated errors remaining: 0
# Total samples processed: 38
# F1 Macro (Baselines): 0.6323232323232323
# F1 Macro (with Feedback): 1.0
# ========================================
#
# [0.00033145 0.00034848]
# Retrieved Feedback:  ['If the vehicles stop before a crosswalk and give way to the pedestrians at the crossing, the rule is complied with.']
# Filtering error samples: ...
# Collecting feedback: ...
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=336x336>
# Sample 39: data/processed_images/traffic/Traffic_Rules_1/0000002.jpg
# Rule: Traffic Rules
# Label: Violated ; Pred: Complied
# Explanation: The car is stopping at a red light, which is a requirement of the rule. The pedestrians are also present in the crosswalk, indicating that the car is giving way to them as required by the rule.
# Retrieved Feedback: ['If the vehicles stop before a crosswalk and give way to the pedestrians at the crossing, the rule is complied with.']
# ========================================
#
# Enter feedback for rule 'Traffic Rules' (or press Enter to skip): If the car is driving at a red light, the rule is violated.
# [0.00033145 0.00034848 0.        ]
# Nice feedback, the error is corrected!
#
# ---------
# Updated Final Feedback:
# [0.00033145 0.00034848 0.        ]
# Meta-rules:
# If the car is driving at a red light, the rule is violated.
# ---------
# Revising prior samples with updated prompt: ...
#   0%|          | 0/39 [00:00<?, ?it/s]
# [0.00030971 0.00048256 0.00044136]
# 4. data/processed_images/traffic/Driving_Distraction_0/0000002.jpg
# Rule: Traffic Rules; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a man driving a car on a road. The rules provided are related to pedestrian crossings, children's crossings, and traffic lights. Since the man is driving a car and not a pedestrian, the rules provided are not applicable to this scenario.
# Revised Explanation: The image shows a man driving a car, but there are no pedestrians or crosswalks visible. Therefore, the rules related to pedestrians and crosswalks do not apply in this scenario.
# ========================================
#
# [0.00028732 0.0004211  0.00031119]
# 9. data/processed_images/traffic/Driving_Distraction_1/0000002.jpg
# Rule: Traffic Rules; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a woman driving a car. The rules provided are related to pedestrians, children's crossings, and traffic lights. Since the woman is driving a car and not a pedestrian, the rules are not applicable in this scenario.
# Revised Explanation: The image shows a woman driving a car. The rules provided are related to pedestrians and crosswalks. Since the woman is driving, the rules are not applicable in this scenario.
# ========================================
#
# [0.         0.00039428 0.00033145]
# 14. data/processed_images/traffic/Pedestrian_Crossing_0/0000002.jpg
# Rule: Traffic Rules; Label: Complied
# Initial Pred: Violated  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows a red car driving on a crosswalk, which is a violation of the rule that states a driver must not drive in a pedestrian crossing. The car is also driving on a crosswalk with people walking, which further emphasizes the violation of the rule.
# Revised Explanation: The image shows a group of people crossing the street at a crosswalk. A car is stopped at the crosswalk, and the pedestrians are giving way to the car. This scenario complies with the rule that a driver must give way to any pedestrian on or entering a pedestrian crossing.
# ========================================
#
# [0.00042202 0.00047334 0.00030505]
# 19. data/processed_images/traffic/Pedestrian_Crossing_1/0000002.jpg
# Rule: Traffic Rules; Label: Complied
# Initial Pred: Complied  -->  Revised Pred: Complied ✅
# Initial Explanation: The vehicles are stopping before the crosswalk and giving way to the pedestrians at the crossing, which is a compliance with the rule.
# Revised Explanation: The image shows people crossing the street at a red light, and cars stopping for them. This indicates that the drivers are giving way to pedestrians at the crossing, which is required by the rule. The presence of traffic lights also supports the fact that the drivers are following the traffic rules.
# ========================================
#
# [0.00037061 0.0004539  0.00032051]
# 24. data/processed_images/traffic/Road_Condition_0/0000002.jpg
# Rule: Traffic Rules; Label: Complied
# Initial Pred: Complied  -->  Revised Pred: Violated ❌
# Initial Explanation: The vehicles are stopping before the crosswalk and giving way to the pedestrians at the crossing, which is complying with the rule.
# Revised Explanation: The car is driving on a road with a pedestrian crossing. It is required to give way to any pedestrian on or entering the pedestrian crossing. Therefore, the rule is violated.
# ========================================
#
# [3.94281942e-04 1.11022302e-16 3.48476672e-04]
# 29. data/processed_images/traffic/Road_Condition_1/0000002.jpg
# Rule: Traffic Rules; Label: Not Applicable
# Initial Pred: Violated  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a fallen power line on the road, which indicates that the rule is not being followed. The rule states that a driver must not stop in an emergency stopping lane. The presence of the fallen power line suggests that there was an emergency that required immediate attention, and the driver did not follow the rule by stopping in the emergency stopping lane.
# Revised Explanation: The image shows a fallen power line and a telephone pole. There are no cars or pedestrians in the scene. Therefore, the rules RS-1.1, RS-1.2, RS-1.3, RS-1.4, RS-1.5, RS-1.6, RS-1.7, RS-1.8, RS-1.9, and RS-1.10 are not applicable in this scenario.
# ========================================
#
# [0.00031083 0.00054788 0.00055382]
# 34. data/processed_images/traffic/Traffic_Rules_0/0000002.jpg
# Rule: Traffic Rules; Label: Complied
# Initial Pred: Complied  -->  Revised Pred: Complied ✅
# Initial Explanation: The pedestrians are using the crosswalk, and the vehicles are stopping to give way to them. This is a compliance with the rule.
# Revised Explanation: The pedestrians are using the crosswalk, and the vehicles are stopping to give way to them. This is a compliance with the rule.
# ========================================
#
# [0.00033145 0.00034848 0.        ]
# 39. data/processed_images/traffic/Traffic_Rules_1/0000002.jpg
# Rule: Traffic Rules; Label: Violated
# Initial Pred: Complied  -->  Revised Pred: Violated ✅
# Initial Explanation: The car is stopping at a red light, which is a requirement of the rule. The pedestrians are also present in the crosswalk, indicating that the car is giving way to them as required by the rule.
# Revised Explanation: The car is driving at a red light, which is a violation of the rule.
# ========================================
#
# Would you like to erase the latest feedback for rule 'Traffic Rules' and try again later? (y/n): n
# Sample 39 completed
# Accumulated corrections made: 8
# Accumulated errors remaining: 1
# Total samples processed: 39
# F1 Macro (Baselines): 0.6649572649572649
# F1 Macro (with Feedback): 0.9552042160737813
# ========================================
#
# [0.00032051]
# ...
# Initial Pred: Violated  -->  Revised Pred: Not Applicable ✅
# Initial Explanation: The image shows a fallen power line on the road, which indicates that the rule is not being followed. The rule states that a driver must not stop in an emergency stopping lane. The presence of the fallen power line suggests that there was an emergency that required immediate attention, and the driver did not follow the rule by stopping in the emergency stopping lane.
# Revised Explanation: The image shows a fallen power line and a telephone pole. There are no cars or pedestrians in the scene. Therefore, the rules RS-1.1, RS-1.2, RS-1.3, RS-1.4, RS-1.5, RS-1.6, RS-1.7, RS-1.8, RS-1.9, and RS-1.10 are not applicable in this scenario.
# ========================================
#
# [0.00031083 0.00054788 0.00055382 0.00056715]
# 34. data/processed_images/traffic/Traffic_Rules_0/0000002.jpg
# Rule: Traffic Rules; Label: Complied
# Initial Pred: Complied  -->  Revised Pred: Complied ✅
# Initial Explanation: The pedestrians are using the crosswalk, and the vehicles are stopping to give way to them. This is a compliance with the rule.
# Revised Explanation: The pedestrians are using the crosswalk, and the vehicles are stopping to give way to them. This is a compliance with the rule.
# ========================================
#
# [0.00033145 0.00034848 0.         0.00037752]
# 39. data/processed_images/traffic/Traffic_Rules_1/0000002.jpg
# Rule: Traffic Rules; Label: Violated
# Initial Pred: Complied  -->  Revised Pred: Violated ✅
# Initial Explanation: The car is stopping at a red light, which is a requirement of the rule. The pedestrians are also present in the crosswalk, indicating that the car is giving way to them as required by the rule.
# Revised Explanation: The car is driving at a red light, which is a violation of the rule.
# ========================================
#
# [0.00035214 0.00032183 0.00037752 0.        ]
# 44. data/processed_images/traffic/Vehicle_Load_0/0000002.jpg
# Rule: Traffic Rules; Label: Complied
# Initial Pred: Not Applicable  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows a car driving on a road with mountains in the background. There are no pedestrians or other vehicles visible in the image. Therefore, the rules related to pedestrian crossings, traffic lights, and one-way roads do not apply in this scenario.
# Revised Explanation: The vehicles are travelling within a single marked lane on a one-way service road. Therefore, the rule is complied with.
# ========================================
#
# Would you like to erase the latest feedback for rule 'Traffic Rules' and try again later? (y/n): n
# Sample 44 completed
# Accumulated corrections made: 9
# Accumulated errors remaining: 1
# Total samples processed: 44
# F1 Macro (Baselines): 0.659481183777859
# F1 Macro (with Feedback): 0.957351290684624
# ========================================
#
# [0.00047616]
# Retrieved Feedback:  ['If the truck is not overloading, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 45 completed
# Accumulated corrections made: 9
# Accumulated errors remaining: 1
# Total samples processed: 45
# F1 Macro (Baselines): 0.644993894993895
# F1 Macro (with Feedback): 0.9582027168234065
# ========================================
#
# [0.00047303]
# Retrieved Feedback:  ['If the driver is focused on driving, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 46 completed
# Accumulated corrections made: 9
# Accumulated errors remaining: 1
# Total samples processed: 46
# F1 Macro (Baselines): 0.6459435626102293
# F1 Macro (with Feedback): 0.9582027168234065
# ========================================
#
# [0.00033449 0.0004508  0.00040119]
# Retrieved Feedback:  ['If the pedestrians are crossing at a crosswalk, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 47 completed
# Accumulated corrections made: 9
# Accumulated errors remaining: 1
# Total samples processed: 47
# F1 Macro (Baselines): 0.6468253968253969
# F1 Macro (with Feedback): 0.9582027168234065
# ========================================
#
# Retrieved Feedback:  []
# Filtering error samples: ...
# Collecting feedback: ...
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=336x336>
# Sample 48: data/processed_images/traffic/Vehicle_Load_1/0000002.jpg
# Rule: Road Condition
# Label: Complied ; Pred: Not Applicable
# Explanation: The image shows a truck with a large pile of items on top, including a bicycle. However, the image does not depict any hazardous area or any relevant vehicle being used in a hazardous area without hazardous area authority. Therefore, the rules RS-1.1, RS-1.2, and RS-1.3 are not applicable to this scenario.
# Retrieved Feedback: []
# ========================================
#
# Enter feedback for rule 'Road Condition' (or press Enter to skip): If the road is clearly seen in undamaged, the image does not depict any hazardous area, the rule is complied with.
# [0.]
# Nice feedback, the error is corrected!
#
# ---------
# Updated Final Feedback:
# [0.]
# Meta-rules:
# If the road is clearly seen in undamaged, the image does not depict any hazardous area, the rule is complied with.
# ---------
# Revising prior samples with updated prompt: ...
#   0%|          | 0/48 [00:00<?, ?it/s]
# [0.00047303]
# 3. data/processed_images/traffic/Driving_Distraction_0/0000002.jpg
# Rule: Road Condition; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Complied ❌
# Initial Explanation: The image shows a man driving a car, but there is no indication of hazardous conditions or any other factors that would require compliance with the rules. Therefore, the rule is not applicable.
# Revised Explanation: The image shows a man driving a car on a road. There are no signs of hazardous areas or any other factors that would indicate a violation of the relevant road laws and advisory signs. Therefore, the rule is complied with.
# ========================================
#
# [0.00035304]
# 8. data/processed_images/traffic/Driving_Distraction_1/0000002.jpg
# Rule: Road Condition; Label: Not Applicable
# Initial Pred: Not Applicable  -->  Revised Pred: Complied ❌
# Initial Explanation: The image shows a woman driving a car and talking on a cell phone. The rules provided are related to driving conditions and the use of relevant vehicles in hazardous areas. However, the image does not depict any violation of these rules. Therefore, the rule set is not applicable to this scenario.
# Revised Explanation: The image shows a woman driving a car and holding a cell phone. The relevant factors include the physical characteristics of the road, the prevailing weather conditions, the level of visibility, the condition of any vehicle the person is driving or riding on the highway, the prevailing traffic conditions, the relevant road laws and advisory signs, and the physical and mental condition of the driver or road user. Since the woman is holding a cell phone, it can be inferred that she is not paying full attention to the road and the relevant factors. Therefore, the rule is complied with.
# ========================================
#
# [0.00033449]
# 13. data/processed_images/traffic/Pedestrian_Crossing_0/0000002.jpg
# Rule: Road Condition; Label: Complied
# Initial Pred: Complied  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows a group of people crossing a street at a crosswalk. They are following the relevant road laws and advisory signs, which include the general rule to drive in a safe manner having regard to all relevant factors. The physical and mental condition of the driver or road user is also taken into account. Therefore, the rule is complied with.
# Revised Explanation: The image shows a group of people crossing a street at a crosswalk. There are no hazardous areas visible in the image. Therefore, the rule is complied with.
# ========================================
#
# [0.0004508]
# 18. data/processed_images/traffic/Pedestrian_Crossing_1/0000002.jpg
# Rule: Road Condition; Label: Complied
# Initial Pred: Complied  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows people walking on a sidewalk and cars driving on the street. The pedestrians are using the sidewalk, which is a safe area for them. The cars are driving on the street, which is a designated area for vehicles. Both the pedestrians and the vehicles are following the relevant road laws and advisory signs. The physical and mental condition of the drivers and road users is also considered. Therefore, the rule is complied with.
# Revised Explanation: The image shows a group of people walking across a street at a crosswalk. There are no hazardous areas visible in the image. Therefore, the rule is complied with.
# ========================================
#
# [0.00048887]
# 23. data/processed_images/traffic/Road_Condition_0/0000002.jpg
# Rule: Road Condition; Label: Complied
# Initial Pred: Complied  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows a blue car driving on a road with a red and white sign in the background. The car is following the road rules and driving in a safe manner, taking into account the physical characteristics of the road, the prevailing weather conditions, the level of visibility, the condition of the vehicle, the prevailing traffic conditions, and the relevant road laws and advisory signs. The driver is also aware of the hazardous area regulations and is not using the relevant vehicle in a hazardous area without hazardous area authority. Therefore, the rule is complied with.
# Revised Explanation: The image shows a blue car driving on a road with a red and white sign. The road appears to be in good condition, and there are no visible hazards. Therefore, the rule is complied with.
# ========================================
#
# [0.00043077]
# 28. data/processed_images/traffic/Road_Condition_1/0000002.jpg
# Rule: Road Condition; Label: Violated
# Initial Pred: Violated  -->  Revised Pred: Complied ❌
# Initial Explanation: The image shows a fallen power line on a wet road, which indicates that the relevant vehicle is not being used in a hazardous area without hazardous area authority. Therefore, the rule is violated.
# Revised Explanation: The image shows a fallen power line on a wet road. The relevant factors include the physical characteristics of the road, the prevailing weather conditions, and the condition of the power line. The person driving a vehicle on the highway must drive in a safe manner having regard to all the relevant factors. The person must not use a relevant vehicle in a hazardous area. Since the power line is fallen and the road is wet, it can be concluded that the rule is complied with.
# ========================================
#
# [0.00040119]
# 33. data/processed_images/traffic/Traffic_Rules_0/0000002.jpg
# Rule: Road Condition; Label: Complied
# Initial Pred: Complied  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows people walking across a crosswalk in the rain. The relevant factors include the physical characteristics of the road, the prevailing weather conditions, the level of visibility, the condition of any vehicle the person is driving or riding on the highway, the prevailing traffic conditions, and the relevant road laws and advisory signs. The person driving the car must drive in a safe manner having regard to all these relevant factors. Therefore, the rule is complied with.
# Revised Explanation: The image shows people walking across a crosswalk in the rain. The relevant factors include the physical characteristics of the road, the prevailing weather conditions, the level of visibility, the condition of any vehicle the person is driving or riding on the highway, the prevailing traffic conditions, and the relevant road laws and advisory signs. The road is clearly seen in undamaged, and the image does not depict any hazardous area. Therefore, the rule is complied with.
# ========================================
#
# [0.00044989]
# 38. data/processed_images/traffic/Traffic_Rules_1/0000002.jpg
# Rule: Road Condition; Label: Complied
# Initial Pred: Complied  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows a red car driving on a street with a traffic light. The car is following the traffic light signals, which indicates that the driver is complying with the relevant road laws and advisory signs. The physical and mental condition of the driver is also considered, as they are able to operate the vehicle safely. Therefore, the rule is complied with.
# Revised Explanation: The image shows a red car driving on a street with a traffic light. The road is clearly seen in undamaged, and there are no hazardous areas visible. Therefore, the rule is complied with.
# ========================================
#
# [0.00038363]
# 43. data/processed_images/traffic/Vehicle_Load_0/0000002.jpg
# Rule: Road Condition; Label: Complied
# Initial Pred: Complied  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows a car driving on a highway with mountains in the background. The car is following another car, and there is a truck in front of it. The relevant factors, such as the physical characteristics of the road, the prevailing weather conditions, the level of visibility, the condition of the vehicles, the prevailing traffic conditions, and the relevant road laws and advisory signs, are all considered in this scenario. The driver is complying with the relevant rules and regulations, ensuring a safe driving experience on the highway. The confidence is 1, as the image clearly shows the compliance with the rules and regulations.
# Revised Explanation: The image shows a car driving on a highway with mountains in the background. The road is clearly seen in undamaged, and there are no signs of hazardous areas. Therefore, the rule is complied with.
# ========================================
#
# [0.]
# 48. data/processed_images/traffic/Vehicle_Load_1/0000002.jpg
# Rule: Road Condition; Label: Complied
# Initial Pred: Not Applicable  -->  Revised Pred: Complied ✅
# Initial Explanation: The image shows a truck with a large pile of items on top, including a bicycle. However, the image does not depict any hazardous area or any relevant vehicle being used in a hazardous area without hazardous area authority. Therefore, the rules RS-1.1, RS-1.2, and RS-1.3 are not applicable to this scenario.
# Revised Explanation: The image shows a truck with a large pile of items on top, including a bicycle. The road is clearly seen in undamaged, and there is no indication of a hazardous area. Therefore, the rule is complied with.
# ========================================
#
# Would you like to erase the latest feedback for rule 'Road Condition' and try again later? (y/n): y
# Sample 48 completed
# Accumulated corrections made: 10
# Accumulated errors remaining: 2
# Total samples processed: 48
# F1 Macro (Baselines): 0.6336173767752715
# F1 Macro (with Feedback): 0.9414141414141414
# ========================================
#
# [0.00033449 0.00043077 0.00044989 0.00038363]
# Retrieved Feedback:  ['If the vehicles stop before a crosswalk and give way to the pedestrians at the crossing, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 49 completed
# Accumulated corrections made: 10
# Accumulated errors remaining: 2
# Total samples processed: 49
# F1 Macro (Baselines): 0.6574269005847954
# F1 Macro (with Feedback): 0.9460761460761461
# ========================================
#
# [0.00048887]
# Retrieved Feedback:  ['If the truck is not overloading, the rule is complied with.']
# Filtering error samples: ...
# All good! No weak samples to collect feedback from.
# Sample 50 completed
# Accumulated corrections made: 10
# Accumulated errors remaining: 2
# Total samples processed: 50
# F1 Macro (Baselines): 0.6759454191033138
# F1 Macro (with Feedback): 0.9494949494949495
# ========================================
#
# Total execution time: 41 min 20 sec
# F1 Macro (Baselines):  0.6759454191033138
# F1 Macro (with Feedback):  0.9494949494949495
